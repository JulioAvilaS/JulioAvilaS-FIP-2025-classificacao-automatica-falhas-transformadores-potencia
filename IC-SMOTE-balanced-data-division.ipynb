# %%
import pandas as pd
import random 
import numpy as np
from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split

# %%
filename = 'Datasets/Ibrahim-dataset/SMOTE-Oversampled-119-dataset/entire_dataset.csv'
df = pd.read_csv(filename)
original_oversampled_dataset = df.values.tolist()
random.shuffle(original_oversampled_dataset)

# %%
df = pd.DataFrame(original_oversampled_dataset)
print(df.columns.tolist())

samples = df.drop(columns=[5])
labels = df[5]
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
df = pd.DataFrame(samples)
df.columns = ['h2', 'ch4', 'c2h2', 'c2h4', 'c2h6']
df.to_csv('Datasets/Ibrahim-dataset/SMOTE-Oversampled-119-dataset/train_samples.csv', index=False)

df = pd.DataFrame(labels)
df.columns = ['act']
df.to_csv('Datasets/Ibrahim-dataset/SMOTE-Oversampled-119-dataset/train_labels.csv', index=False)
