# %%
import csv

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import sklearn.metrics as metrics

from tensorflow import keras
from keras.callbacks import EarlyStopping
from keras.models import Model, Sequential, load_model, save_model
from keras.layers import Activation, Dense, Input, Dropout, Flatten, BatchNormalization
from keras.optimizers import Adam
from keras.metrics import categorical_crossentropy, Precision, Recall
from sklearn.preprocessing import RobustScaler, MinMaxScaler
from keras.regularizers import l2

from sklearn.metrics import classification_report, confusion_matrix, balanced_accuracy_score, accuracy_score, precision_score, recall_score, f1_score, precision_recall_fscore_support, ConfusionMatrixDisplay

# %% [markdown]
# # Leitura dos registros de treinamento:

# %%
csv_path_training_gases = "Datasets/Ibrahim-dataset/Gas-80-20-dataset/train_samples.csv"
with open(csv_path_training_gases, mode = 'r') as file:
    csv_reader_training_gases = csv.reader(file)
    next(csv_reader_training_gases)

    train_samples = []
    for row in csv_reader_training_gases:
        train_samples.append([float(x) for x in row])
        
csv_path_training_faults = "Datasets/Ibrahim-dataset/Gas-80-20-dataset/train_labels.csv"
with open(csv_path_training_faults, mode = 'r') as file:
    csv_reader_training_faults = csv.reader(file)
    next(csv_reader_training_faults)

    train_labels = []
    for row in csv_reader_training_faults:
        train_labels.append(float(row[0]))

# %% [markdown]
# # Normalização dos treinos:

# %%
# Adiciona uma pequena constante para evitar log(0)
# epsilon = 1e-10

# Normalização logarítmica dos gases
train_samples = np.array(train_samples)
# train_samples = np.log(train_samples + epsilon)


scaler = RobustScaler()

# # normalização dos gases com robust scaler
scaled_train_samples = scaler.fit_transform(train_samples)

# Normalização dos rótulos
train_labels = np.array(train_labels)
train_labels = train_labels.flatten()
int_scaled_train_labels = (train_labels.astype(float)).astype(int)
int_scaled_train_labels = np.array(int_scaled_train_labels)

# %%
import seaborn as sns
sns.countplot(x=int_scaled_train_labels)
plt.title("Distribuição das Classes (Treino)")
plt.show()

# %% [markdown]
# # Criação do modelo da Rede neural:

# %%
def create_functional_model():
    model = Sequential([
        Input(shape=(5,)),
        Dense(32, activation='relu', kernel_regularizer=l2(0.001)), 
        BatchNormalization(),
        Dropout(0.5),
        Dense(16, activation='relu'),
        Dense(7, activation='softmax')
    ]) 

    model.compile(optimizer=Adam(learning_rate=0.002),
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

early_stopping = EarlyStopping(
    monitor='val_loss',
    patience=500,
    mode='min',
    restore_best_weights=True
)

functional_model = create_functional_model()
history = functional_model.fit(scaled_train_samples, int_scaled_train_labels, validation_split=0.2, epochs=1500, batch_size=64, callbacks=[early_stopping], verbose=2)
# Out:
# Epoch 1/1500
# 6/6 - 1s - loss: 2.1415 - accuracy: 0.1239 - val_loss: 2.6304 - val_accuracy: 0.3735 - 947ms/epoch - 158ms/step
# Epoch 2/1500
# 6/6 - 0s - loss: 2.0195 - accuracy: 0.1994 - val_loss: 2.4459 - val_accuracy: 0.4096 - 42ms/epoch - 7ms/step
# Epoch 3/1500
# 6/6 - 0s - loss: 1.9555 - accuracy: 0.2417 - val_loss: 2.3018 - val_accuracy: 0.4699 - 45ms/epoch - 8ms/step
# Epoch 4/1500
# 6/6 - 0s - loss: 1.8463 - accuracy: 0.3021 - val_loss: 2.2231 - val_accuracy: 0.4458 - 36ms/epoch - 6ms/step
# Epoch 5/1500
# 6/6 - 0s - loss: 1.7426 - accuracy: 0.3535 - val_loss: 2.1791 - val_accuracy: 0.4819 - 30ms/epoch - 5ms/step
# Epoch 6/1500
# 6/6 - 0s - loss: 1.7426 - accuracy: 0.3172 - val_loss: 2.1428 - val_accuracy: 0.4819 - 34ms/epoch - 6ms/step
# Epoch 7/1500
# 6/6 - 0s - loss: 1.7389 - accuracy: 0.3686 - val_loss: 2.1303 - val_accuracy: 0.4819 - 33ms/epoch - 6ms/step
# Epoch 8/1500
# 6/6 - 0s - loss: 1.6785 - accuracy: 0.3837 - val_loss: 2.0979 - val_accuracy: 0.4940 - 31ms/epoch - 5ms/step
# Epoch 9/1500
# 6/6 - 0s - loss: 1.5877 - accuracy: 0.4169 - val_loss: 2.0351 - val_accuracy: 0.5060 - 32ms/epoch - 5ms/step
# Epoch 10/1500
# 6/6 - 0s - loss: 1.6091 - accuracy: 0.3958 - val_loss: 1.9727 - val_accuracy: 0.5301 - 31ms/epoch - 5ms/step
# Epoch 11/1500
# 6/6 - 0s - loss: 1.5328 - accuracy: 0.4350 - val_loss: 1.9311 - val_accuracy: 0.5301 - 36ms/epoch - 6ms/step
# Epoch 12/1500
# 6/6 - 0s - loss: 1.5170 - accuracy: 0.4260 - val_loss: 1.9023 - val_accuracy: 0.5542 - 34ms/epoch - 6ms/step
# Epoch 13/1500
# 6/6 - 0s - loss: 1.4553 - accuracy: 0.4924 - val_loss: 1.8636 - val_accuracy: 0.5542 - 31ms/epoch - 5ms/step
# Epoch 14/1500
# 6/6 - 0s - loss: 1.4899 - accuracy: 0.5166 - val_loss: 1.8352 - val_accuracy: 0.5542 - 30ms/epoch - 5ms/step
# Epoch 15/1500
# 6/6 - 0s - loss: 1.4834 - accuracy: 0.4532 - val_loss: 1.8290 - val_accuracy: 0.5542 - 30ms/epoch - 5ms/step
# Epoch 16/1500
# 6/6 - 0s - loss: 1.4183 - accuracy: 0.4773 - val_loss: 1.8135 - val_accuracy: 0.5422 - 32ms/epoch - 5ms/step
# Epoch 17/1500
# 6/6 - 0s - loss: 1.4254 - accuracy: 0.4834 - val_loss: 1.7984 - val_accuracy: 0.5663 - 32ms/epoch - 5ms/step
# Epoch 18/1500
# 6/6 - 0s - loss: 1.3584 - accuracy: 0.4864 - val_loss: 1.7831 - val_accuracy: 0.5542 - 36ms/epoch - 6ms/step
# Epoch 19/1500
# 6/6 - 0s - loss: 1.4294 - accuracy: 0.4834 - val_loss: 1.7615 - val_accuracy: 0.5301 - 33ms/epoch - 5ms/step
# Epoch 20/1500
# 6/6 - 0s - loss: 1.3965 - accuracy: 0.4834 - val_loss: 1.7440 - val_accuracy: 0.5060 - 31ms/epoch - 5ms/step
# Epoch 21/1500
# 6/6 - 0s - loss: 1.3731 - accuracy: 0.4955 - val_loss: 1.7277 - val_accuracy: 0.5422 - 32ms/epoch - 5ms/step
# Epoch 22/1500
# 6/6 - 0s - loss: 1.3858 - accuracy: 0.4955 - val_loss: 1.7110 - val_accuracy: 0.5422 - 33ms/epoch - 6ms/step
# Epoch 23/1500
# 6/6 - 0s - loss: 1.3761 - accuracy: 0.5076 - val_loss: 1.6856 - val_accuracy: 0.5904 - 39ms/epoch - 6ms/step
# Epoch 24/1500
# 6/6 - 0s - loss: 1.3165 - accuracy: 0.5347 - val_loss: 1.6726 - val_accuracy: 0.6024 - 38ms/epoch - 6ms/step
# Epoch 25/1500
# 6/6 - 0s - loss: 1.2651 - accuracy: 0.5468 - val_loss: 1.6547 - val_accuracy: 0.6145 - 40ms/epoch - 7ms/step
# Epoch 26/1500
# 6/6 - 0s - loss: 1.2312 - accuracy: 0.5468 - val_loss: 1.6285 - val_accuracy: 0.6386 - 35ms/epoch - 6ms/step
# Epoch 27/1500
# 6/6 - 0s - loss: 1.2640 - accuracy: 0.4773 - val_loss: 1.6107 - val_accuracy: 0.6386 - 67ms/epoch - 11ms/step
# Epoch 28/1500
# 6/6 - 0s - loss: 1.2816 - accuracy: 0.5287 - val_loss: 1.6038 - val_accuracy: 0.5301 - 52ms/epoch - 9ms/step
# Epoch 29/1500
# 6/6 - 0s - loss: 1.2269 - accuracy: 0.5287 - val_loss: 1.6014 - val_accuracy: 0.5060 - 41ms/epoch - 7ms/step
# Epoch 30/1500
# 6/6 - 0s - loss: 1.2134 - accuracy: 0.6133 - val_loss: 1.5983 - val_accuracy: 0.5301 - 87ms/epoch - 15ms/step
# Epoch 31/1500
# 6/6 - 0s - loss: 1.1731 - accuracy: 0.5529 - val_loss: 1.5984 - val_accuracy: 0.5422 - 63ms/epoch - 10ms/step
# Epoch 32/1500
# 6/6 - 0s - loss: 1.2934 - accuracy: 0.5317 - val_loss: 1.5924 - val_accuracy: 0.5783 - 57ms/epoch - 9ms/step
# Epoch 33/1500
# 6/6 - 0s - loss: 1.1871 - accuracy: 0.5680 - val_loss: 1.5825 - val_accuracy: 0.5904 - 46ms/epoch - 8ms/step
# Epoch 34/1500
# 6/6 - 0s - loss: 1.2139 - accuracy: 0.5498 - val_loss: 1.5661 - val_accuracy: 0.5904 - 57ms/epoch - 9ms/step
# Epoch 35/1500
# 6/6 - 0s - loss: 1.1109 - accuracy: 0.5982 - val_loss: 1.5609 - val_accuracy: 0.6024 - 45ms/epoch - 8ms/step
# Epoch 36/1500
# 6/6 - 0s - loss: 1.1511 - accuracy: 0.6133 - val_loss: 1.5440 - val_accuracy: 0.6024 - 39ms/epoch - 6ms/step
# Epoch 37/1500
# 6/6 - 0s - loss: 1.1556 - accuracy: 0.5619 - val_loss: 1.5295 - val_accuracy: 0.6024 - 39ms/epoch - 7ms/step
# Epoch 38/1500
# 6/6 - 0s - loss: 1.1657 - accuracy: 0.5529 - val_loss: 1.5158 - val_accuracy: 0.6024 - 39ms/epoch - 7ms/step
# Epoch 39/1500
# 6/6 - 0s - loss: 1.1546 - accuracy: 0.5861 - val_loss: 1.5014 - val_accuracy: 0.5904 - 37ms/epoch - 6ms/step
# Epoch 40/1500
# 6/6 - 0s - loss: 1.1086 - accuracy: 0.5891 - val_loss: 1.4804 - val_accuracy: 0.6265 - 32ms/epoch - 5ms/step
# Epoch 41/1500
# 6/6 - 0s - loss: 1.1507 - accuracy: 0.5770 - val_loss: 1.4607 - val_accuracy: 0.6145 - 37ms/epoch - 6ms/step
# Epoch 42/1500
# 6/6 - 0s - loss: 1.1197 - accuracy: 0.5861 - val_loss: 1.4483 - val_accuracy: 0.6386 - 33ms/epoch - 6ms/step
# Epoch 43/1500
# 6/6 - 0s - loss: 1.1499 - accuracy: 0.5227 - val_loss: 1.4353 - val_accuracy: 0.6386 - 32ms/epoch - 5ms/step
# Epoch 44/1500
# 6/6 - 0s - loss: 1.0947 - accuracy: 0.6042 - val_loss: 1.4244 - val_accuracy: 0.6386 - 32ms/epoch - 5ms/step
# Epoch 45/1500
# 6/6 - 0s - loss: 1.0832 - accuracy: 0.5921 - val_loss: 1.4104 - val_accuracy: 0.6627 - 37ms/epoch - 6ms/step
# Epoch 46/1500
# 6/6 - 0s - loss: 1.1101 - accuracy: 0.5861 - val_loss: 1.4067 - val_accuracy: 0.6506 - 72ms/epoch - 12ms/step
# Epoch 47/1500
# 6/6 - 0s - loss: 1.0887 - accuracy: 0.6284 - val_loss: 1.4082 - val_accuracy: 0.6506 - 58ms/epoch - 10ms/step
# Epoch 48/1500
# 6/6 - 0s - loss: 1.1012 - accuracy: 0.5589 - val_loss: 1.4108 - val_accuracy: 0.6386 - 35ms/epoch - 6ms/step
# Epoch 49/1500
# 6/6 - 0s - loss: 1.0881 - accuracy: 0.5982 - val_loss: 1.4018 - val_accuracy: 0.6747 - 38ms/epoch - 6ms/step
# Epoch 50/1500
# 6/6 - 0s - loss: 1.0877 - accuracy: 0.5831 - val_loss: 1.3945 - val_accuracy: 0.6747 - 39ms/epoch - 7ms/step
# Epoch 51/1500
# 6/6 - 0s - loss: 1.0715 - accuracy: 0.6133 - val_loss: 1.3902 - val_accuracy: 0.6747 - 62ms/epoch - 10ms/step
# Epoch 52/1500
# 6/6 - 0s - loss: 1.0658 - accuracy: 0.5982 - val_loss: 1.3923 - val_accuracy: 0.6747 - 34ms/epoch - 6ms/step
# Epoch 53/1500
# 6/6 - 0s - loss: 1.0445 - accuracy: 0.6163 - val_loss: 1.3960 - val_accuracy: 0.6747 - 38ms/epoch - 6ms/step
# Epoch 54/1500
# 6/6 - 0s - loss: 1.0103 - accuracy: 0.6133 - val_loss: 1.3948 - val_accuracy: 0.6747 - 32ms/epoch - 5ms/step
# Epoch 55/1500
# 6/6 - 0s - loss: 1.0769 - accuracy: 0.6103 - val_loss: 1.3947 - val_accuracy: 0.6627 - 36ms/epoch - 6ms/step
# Epoch 56/1500
# 6/6 - 0s - loss: 1.0073 - accuracy: 0.6314 - val_loss: 1.3890 - val_accuracy: 0.6627 - 37ms/epoch - 6ms/step
# Epoch 57/1500
# 6/6 - 0s - loss: 0.9469 - accuracy: 0.6375 - val_loss: 1.3790 - val_accuracy: 0.6506 - 39ms/epoch - 7ms/step
# Epoch 58/1500
# 6/6 - 0s - loss: 1.0004 - accuracy: 0.6495 - val_loss: 1.3730 - val_accuracy: 0.6506 - 35ms/epoch - 6ms/step
# Epoch 59/1500
# 6/6 - 0s - loss: 0.9967 - accuracy: 0.6254 - val_loss: 1.3737 - val_accuracy: 0.6506 - 35ms/epoch - 6ms/step
# Epoch 60/1500
# 6/6 - 0s - loss: 1.0112 - accuracy: 0.6314 - val_loss: 1.3709 - val_accuracy: 0.6627 - 68ms/epoch - 11ms/step
# Epoch 61/1500
# 6/6 - 0s - loss: 0.9184 - accuracy: 0.6647 - val_loss: 1.3629 - val_accuracy: 0.6386 - 58ms/epoch - 10ms/step
# Epoch 62/1500
# 6/6 - 0s - loss: 1.0392 - accuracy: 0.6344 - val_loss: 1.3470 - val_accuracy: 0.6627 - 43ms/epoch - 7ms/step
# Epoch 63/1500
# 6/6 - 0s - loss: 0.9135 - accuracy: 0.6707 - val_loss: 1.3411 - val_accuracy: 0.6024 - 31ms/epoch - 5ms/step
# Epoch 64/1500
# 6/6 - 0s - loss: 0.9622 - accuracy: 0.6133 - val_loss: 1.3370 - val_accuracy: 0.6145 - 32ms/epoch - 5ms/step
# Epoch 65/1500
# 6/6 - 0s - loss: 0.9636 - accuracy: 0.6647 - val_loss: 1.3097 - val_accuracy: 0.6024 - 34ms/epoch - 6ms/step
# Epoch 66/1500
# 6/6 - 0s - loss: 1.0668 - accuracy: 0.6012 - val_loss: 1.3054 - val_accuracy: 0.6145 - 33ms/epoch - 5ms/step
# Epoch 67/1500
# 6/6 - 0s - loss: 0.9634 - accuracy: 0.6375 - val_loss: 1.3075 - val_accuracy: 0.6386 - 34ms/epoch - 6ms/step
# Epoch 68/1500
# 6/6 - 0s - loss: 0.8723 - accuracy: 0.6526 - val_loss: 1.3120 - val_accuracy: 0.6386 - 81ms/epoch - 14ms/step
# Epoch 69/1500
# 6/6 - 0s - loss: 0.9840 - accuracy: 0.6224 - val_loss: 1.3121 - val_accuracy: 0.6386 - 31ms/epoch - 5ms/step
# Epoch 70/1500
# 6/6 - 0s - loss: 0.9458 - accuracy: 0.6435 - val_loss: 1.3021 - val_accuracy: 0.6265 - 31ms/epoch - 5ms/step
# Epoch 71/1500
# 6/6 - 0s - loss: 0.9064 - accuracy: 0.6737 - val_loss: 1.3051 - val_accuracy: 0.5783 - 30ms/epoch - 5ms/step
# Epoch 72/1500
# 6/6 - 0s - loss: 0.9681 - accuracy: 0.6435 - val_loss: 1.2913 - val_accuracy: 0.6024 - 31ms/epoch - 5ms/step
# Epoch 73/1500
# 6/6 - 0s - loss: 0.9529 - accuracy: 0.6133 - val_loss: 1.2674 - val_accuracy: 0.6265 - 31ms/epoch - 5ms/step
# Epoch 74/1500
# 6/6 - 0s - loss: 0.9222 - accuracy: 0.6586 - val_loss: 1.2617 - val_accuracy: 0.6145 - 30ms/epoch - 5ms/step
# Epoch 75/1500
# 6/6 - 0s - loss: 0.9337 - accuracy: 0.6495 - val_loss: 1.2528 - val_accuracy: 0.6145 - 30ms/epoch - 5ms/step
# Epoch 76/1500
# 6/6 - 0s - loss: 0.9188 - accuracy: 0.6344 - val_loss: 1.2326 - val_accuracy: 0.6145 - 28ms/epoch - 5ms/step
# Epoch 77/1500
# 6/6 - 0s - loss: 0.9395 - accuracy: 0.6405 - val_loss: 1.2210 - val_accuracy: 0.6627 - 78ms/epoch - 13ms/step
# Epoch 78/1500
# 6/6 - 0s - loss: 0.9168 - accuracy: 0.6707 - val_loss: 1.2174 - val_accuracy: 0.6386 - 31ms/epoch - 5ms/step
# Epoch 79/1500
# 6/6 - 0s - loss: 0.9256 - accuracy: 0.6707 - val_loss: 1.2232 - val_accuracy: 0.6145 - 30ms/epoch - 5ms/step
# Epoch 80/1500
# 6/6 - 0s - loss: 0.9040 - accuracy: 0.6465 - val_loss: 1.2399 - val_accuracy: 0.5542 - 29ms/epoch - 5ms/step
# Epoch 81/1500
# 6/6 - 0s - loss: 0.8897 - accuracy: 0.6556 - val_loss: 1.2363 - val_accuracy: 0.5783 - 31ms/epoch - 5ms/step
# Epoch 82/1500
# 6/6 - 0s - loss: 0.9367 - accuracy: 0.6344 - val_loss: 1.2325 - val_accuracy: 0.5783 - 31ms/epoch - 5ms/step
# Epoch 83/1500
# 6/6 - 0s - loss: 0.9117 - accuracy: 0.6737 - val_loss: 1.2266 - val_accuracy: 0.5904 - 32ms/epoch - 5ms/step
# Epoch 84/1500
# 6/6 - 0s - loss: 0.8445 - accuracy: 0.6707 - val_loss: 1.2125 - val_accuracy: 0.6024 - 32ms/epoch - 5ms/step
# Epoch 85/1500
# 6/6 - 0s - loss: 0.8863 - accuracy: 0.6495 - val_loss: 1.1984 - val_accuracy: 0.6145 - 31ms/epoch - 5ms/step
# Epoch 86/1500
# 6/6 - 0s - loss: 0.8978 - accuracy: 0.6677 - val_loss: 1.1782 - val_accuracy: 0.6386 - 31ms/epoch - 5ms/step
# Epoch 87/1500
# 6/6 - 0s - loss: 0.9575 - accuracy: 0.6284 - val_loss: 1.1619 - val_accuracy: 0.6867 - 30ms/epoch - 5ms/step
# Epoch 88/1500
# 6/6 - 0s - loss: 0.8990 - accuracy: 0.6435 - val_loss: 1.1603 - val_accuracy: 0.6988 - 31ms/epoch - 5ms/step
# Epoch 89/1500
# 6/6 - 0s - loss: 0.9097 - accuracy: 0.6586 - val_loss: 1.1691 - val_accuracy: 0.6627 - 32ms/epoch - 5ms/step
# Epoch 90/1500
# 6/6 - 0s - loss: 0.8435 - accuracy: 0.6858 - val_loss: 1.1674 - val_accuracy: 0.6747 - 29ms/epoch - 5ms/step
# Epoch 91/1500
# 6/6 - 0s - loss: 0.8776 - accuracy: 0.6677 - val_loss: 1.1648 - val_accuracy: 0.6627 - 27ms/epoch - 5ms/step
# Epoch 92/1500
# 6/6 - 0s - loss: 0.8920 - accuracy: 0.6918 - val_loss: 1.1626 - val_accuracy: 0.6627 - 31ms/epoch - 5ms/step
# Epoch 93/1500
# 6/6 - 0s - loss: 0.8776 - accuracy: 0.6707 - val_loss: 1.1630 - val_accuracy: 0.6506 - 30ms/epoch - 5ms/step
# Epoch 94/1500
# 6/6 - 0s - loss: 0.8939 - accuracy: 0.6918 - val_loss: 1.1666 - val_accuracy: 0.6627 - 29ms/epoch - 5ms/step
# Epoch 95/1500
# 6/6 - 0s - loss: 0.8388 - accuracy: 0.6828 - val_loss: 1.1622 - val_accuracy: 0.6627 - 31ms/epoch - 5ms/step
# Epoch 96/1500
# 6/6 - 0s - loss: 0.8919 - accuracy: 0.6888 - val_loss: 1.1578 - val_accuracy: 0.6627 - 30ms/epoch - 5ms/step
# Epoch 97/1500
# 6/6 - 0s - loss: 0.9268 - accuracy: 0.6254 - val_loss: 1.1604 - val_accuracy: 0.6988 - 33ms/epoch - 6ms/step
# Epoch 98/1500
# 6/6 - 0s - loss: 0.9019 - accuracy: 0.6526 - val_loss: 1.1600 - val_accuracy: 0.7108 - 30ms/epoch - 5ms/step
# Epoch 99/1500
# 6/6 - 0s - loss: 0.8515 - accuracy: 0.6828 - val_loss: 1.1492 - val_accuracy: 0.7108 - 31ms/epoch - 5ms/step
# Epoch 100/1500
# 6/6 - 0s - loss: 0.8925 - accuracy: 0.6979 - val_loss: 1.1441 - val_accuracy: 0.7108 - 30ms/epoch - 5ms/step
# Epoch 101/1500
# 6/6 - 0s - loss: 0.9121 - accuracy: 0.6586 - val_loss: 1.2081 - val_accuracy: 0.6867 - 31ms/epoch - 5ms/step
# Epoch 102/1500
# 6/6 - 0s - loss: 0.8420 - accuracy: 0.7009 - val_loss: 1.1397 - val_accuracy: 0.6747 - 30ms/epoch - 5ms/step
# Epoch 103/1500
# 6/6 - 0s - loss: 0.8458 - accuracy: 0.6949 - val_loss: 1.1076 - val_accuracy: 0.6988 - 31ms/epoch - 5ms/step
# Epoch 104/1500
# 6/6 - 0s - loss: 0.8789 - accuracy: 0.6798 - val_loss: 1.0803 - val_accuracy: 0.7229 - 34ms/epoch - 6ms/step
# Epoch 105/1500
# 6/6 - 0s - loss: 0.8648 - accuracy: 0.6828 - val_loss: 1.0445 - val_accuracy: 0.7229 - 32ms/epoch - 5ms/step
# Epoch 106/1500
# 6/6 - 0s - loss: 0.8424 - accuracy: 0.7372 - val_loss: 1.0159 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 107/1500
# 6/6 - 0s - loss: 0.8510 - accuracy: 0.6828 - val_loss: 1.0089 - val_accuracy: 0.7229 - 31ms/epoch - 5ms/step
# Epoch 108/1500
# 6/6 - 0s - loss: 0.8933 - accuracy: 0.6556 - val_loss: 1.0592 - val_accuracy: 0.7470 - 31ms/epoch - 5ms/step
# Epoch 109/1500
# 6/6 - 0s - loss: 0.8552 - accuracy: 0.7009 - val_loss: 1.0718 - val_accuracy: 0.7470 - 30ms/epoch - 5ms/step
# Epoch 110/1500
# 6/6 - 0s - loss: 0.8591 - accuracy: 0.6556 - val_loss: 1.0776 - val_accuracy: 0.7349 - 33ms/epoch - 5ms/step
# Epoch 111/1500
# 6/6 - 0s - loss: 0.7943 - accuracy: 0.7130 - val_loss: 1.0818 - val_accuracy: 0.7108 - 33ms/epoch - 6ms/step
# Epoch 112/1500
# 6/6 - 0s - loss: 0.8483 - accuracy: 0.6918 - val_loss: 1.0944 - val_accuracy: 0.7108 - 30ms/epoch - 5ms/step
# Epoch 113/1500
# 6/6 - 0s - loss: 0.8050 - accuracy: 0.6949 - val_loss: 1.0946 - val_accuracy: 0.6988 - 30ms/epoch - 5ms/step
# Epoch 114/1500
# 6/6 - 0s - loss: 0.8126 - accuracy: 0.6918 - val_loss: 1.0544 - val_accuracy: 0.6988 - 28ms/epoch - 5ms/step
# Epoch 115/1500
# 6/6 - 0s - loss: 0.8251 - accuracy: 0.6888 - val_loss: 1.0366 - val_accuracy: 0.6867 - 29ms/epoch - 5ms/step
# Epoch 116/1500
# 6/6 - 0s - loss: 0.7853 - accuracy: 0.6979 - val_loss: 1.0509 - val_accuracy: 0.6867 - 29ms/epoch - 5ms/step
# Epoch 117/1500
# 6/6 - 0s - loss: 0.8260 - accuracy: 0.6828 - val_loss: 1.0810 - val_accuracy: 0.6867 - 28ms/epoch - 5ms/step
# Epoch 118/1500
# 6/6 - 0s - loss: 0.8977 - accuracy: 0.6707 - val_loss: 1.1169 - val_accuracy: 0.6627 - 37ms/epoch - 6ms/step
# Epoch 119/1500
# 6/6 - 0s - loss: 0.8328 - accuracy: 0.6767 - val_loss: 1.1096 - val_accuracy: 0.6627 - 32ms/epoch - 5ms/step
# Epoch 120/1500
# 6/6 - 0s - loss: 0.8044 - accuracy: 0.7009 - val_loss: 1.0972 - val_accuracy: 0.6627 - 32ms/epoch - 5ms/step
# Epoch 121/1500
# 6/6 - 0s - loss: 0.7760 - accuracy: 0.7251 - val_loss: 1.0928 - val_accuracy: 0.6506 - 33ms/epoch - 5ms/step
# Epoch 122/1500
# 6/6 - 0s - loss: 0.8754 - accuracy: 0.6828 - val_loss: 1.0876 - val_accuracy: 0.6747 - 28ms/epoch - 5ms/step
# Epoch 123/1500
# 6/6 - 0s - loss: 0.7790 - accuracy: 0.6798 - val_loss: 1.0746 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 124/1500
# 6/6 - 0s - loss: 0.8708 - accuracy: 0.6526 - val_loss: 1.0627 - val_accuracy: 0.7349 - 30ms/epoch - 5ms/step
# Epoch 125/1500
# 6/6 - 0s - loss: 0.8188 - accuracy: 0.6979 - val_loss: 1.0665 - val_accuracy: 0.7349 - 29ms/epoch - 5ms/step
# Epoch 126/1500
# 6/6 - 0s - loss: 0.7842 - accuracy: 0.6798 - val_loss: 1.0755 - val_accuracy: 0.7108 - 30ms/epoch - 5ms/step
# Epoch 127/1500
# 6/6 - 0s - loss: 0.8361 - accuracy: 0.7100 - val_loss: 1.0774 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 128/1500
# 6/6 - 0s - loss: 0.8315 - accuracy: 0.6647 - val_loss: 1.0693 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 129/1500
# 6/6 - 0s - loss: 0.7634 - accuracy: 0.6828 - val_loss: 1.0683 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 130/1500
# 6/6 - 0s - loss: 0.8389 - accuracy: 0.6828 - val_loss: 1.0671 - val_accuracy: 0.7108 - 30ms/epoch - 5ms/step
# Epoch 131/1500
# 6/6 - 0s - loss: 0.7975 - accuracy: 0.7009 - val_loss: 0.9999 - val_accuracy: 0.6988 - 31ms/epoch - 5ms/step
# Epoch 132/1500
# 6/6 - 0s - loss: 0.9004 - accuracy: 0.6616 - val_loss: 0.9760 - val_accuracy: 0.6988 - 32ms/epoch - 5ms/step
# Epoch 133/1500
# 6/6 - 0s - loss: 0.9029 - accuracy: 0.6647 - val_loss: 1.0642 - val_accuracy: 0.7108 - 31ms/epoch - 5ms/step
# Epoch 134/1500
# 6/6 - 0s - loss: 0.7037 - accuracy: 0.7281 - val_loss: 1.0757 - val_accuracy: 0.7108 - 29ms/epoch - 5ms/step
# Epoch 135/1500
# 6/6 - 0s - loss: 0.7930 - accuracy: 0.7039 - val_loss: 1.0683 - val_accuracy: 0.7108 - 31ms/epoch - 5ms/step
# Epoch 136/1500
# 6/6 - 0s - loss: 0.8683 - accuracy: 0.6737 - val_loss: 1.1036 - val_accuracy: 0.7108 - 29ms/epoch - 5ms/step
# Epoch 137/1500
# 6/6 - 0s - loss: 0.8120 - accuracy: 0.6767 - val_loss: 1.0939 - val_accuracy: 0.6506 - 31ms/epoch - 5ms/step
# Epoch 138/1500
# 6/6 - 0s - loss: 0.8540 - accuracy: 0.6858 - val_loss: 0.9645 - val_accuracy: 0.6747 - 31ms/epoch - 5ms/step
# Epoch 139/1500
# 6/6 - 0s - loss: 0.8163 - accuracy: 0.6737 - val_loss: 0.9523 - val_accuracy: 0.7229 - 31ms/epoch - 5ms/step
# Epoch 140/1500
# 6/6 - 0s - loss: 0.8403 - accuracy: 0.6949 - val_loss: 0.9556 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 141/1500
# 6/6 - 0s - loss: 0.7957 - accuracy: 0.7281 - val_loss: 0.9525 - val_accuracy: 0.7470 - 30ms/epoch - 5ms/step
# Epoch 142/1500
# 6/6 - 0s - loss: 0.8005 - accuracy: 0.6888 - val_loss: 0.9538 - val_accuracy: 0.7108 - 31ms/epoch - 5ms/step
# Epoch 143/1500
# 6/6 - 0s - loss: 0.7578 - accuracy: 0.7281 - val_loss: 0.9553 - val_accuracy: 0.7470 - 30ms/epoch - 5ms/step
# Epoch 144/1500
# 6/6 - 0s - loss: 0.7783 - accuracy: 0.6828 - val_loss: 0.9469 - val_accuracy: 0.7470 - 31ms/epoch - 5ms/step
# Epoch 145/1500
# 6/6 - 0s - loss: 0.8149 - accuracy: 0.6677 - val_loss: 0.9503 - val_accuracy: 0.7831 - 28ms/epoch - 5ms/step
# Epoch 146/1500
# 6/6 - 0s - loss: 0.7570 - accuracy: 0.7130 - val_loss: 1.0056 - val_accuracy: 0.7590 - 32ms/epoch - 5ms/step
# Epoch 147/1500
# 6/6 - 0s - loss: 0.8243 - accuracy: 0.7100 - val_loss: 1.0183 - val_accuracy: 0.7229 - 29ms/epoch - 5ms/step
# Epoch 148/1500
# 6/6 - 0s - loss: 0.8109 - accuracy: 0.7009 - val_loss: 1.0168 - val_accuracy: 0.6988 - 30ms/epoch - 5ms/step
# Epoch 149/1500
# 6/6 - 0s - loss: 0.8205 - accuracy: 0.6979 - val_loss: 1.0198 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 150/1500
# 6/6 - 0s - loss: 0.7597 - accuracy: 0.6828 - val_loss: 0.9694 - val_accuracy: 0.7470 - 33ms/epoch - 6ms/step
# Epoch 151/1500
# 6/6 - 0s - loss: 0.8115 - accuracy: 0.6888 - val_loss: 0.9623 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 152/1500
# 6/6 - 0s - loss: 0.8835 - accuracy: 0.6888 - val_loss: 0.9654 - val_accuracy: 0.7349 - 29ms/epoch - 5ms/step
# Epoch 153/1500
# 6/6 - 0s - loss: 0.7312 - accuracy: 0.7311 - val_loss: 0.9935 - val_accuracy: 0.7229 - 28ms/epoch - 5ms/step
# Epoch 154/1500
# 6/6 - 0s - loss: 0.7648 - accuracy: 0.7039 - val_loss: 0.9963 - val_accuracy: 0.7349 - 36ms/epoch - 6ms/step
# Epoch 155/1500
# 6/6 - 0s - loss: 0.7496 - accuracy: 0.7221 - val_loss: 0.9952 - val_accuracy: 0.7470 - 32ms/epoch - 5ms/step
# Epoch 156/1500
# 6/6 - 0s - loss: 0.7586 - accuracy: 0.7432 - val_loss: 1.0015 - val_accuracy: 0.7590 - 31ms/epoch - 5ms/step
# Epoch 157/1500
# 6/6 - 0s - loss: 0.7823 - accuracy: 0.7009 - val_loss: 1.0041 - val_accuracy: 0.7590 - 35ms/epoch - 6ms/step
# Epoch 158/1500
# 6/6 - 0s - loss: 0.8218 - accuracy: 0.6888 - val_loss: 1.0159 - val_accuracy: 0.7470 - 37ms/epoch - 6ms/step
# Epoch 159/1500
# 6/6 - 0s - loss: 0.8000 - accuracy: 0.6949 - val_loss: 1.0318 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 160/1500
# 6/6 - 0s - loss: 0.8257 - accuracy: 0.6586 - val_loss: 1.0236 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 161/1500
# 6/6 - 0s - loss: 0.8156 - accuracy: 0.6828 - val_loss: 0.9913 - val_accuracy: 0.7108 - 31ms/epoch - 5ms/step
# Epoch 162/1500
# 6/6 - 0s - loss: 0.7908 - accuracy: 0.6888 - val_loss: 0.9905 - val_accuracy: 0.7108 - 29ms/epoch - 5ms/step
# Epoch 163/1500
# 6/6 - 0s - loss: 0.7802 - accuracy: 0.7039 - val_loss: 0.9967 - val_accuracy: 0.7108 - 30ms/epoch - 5ms/step
# Epoch 164/1500
# 6/6 - 0s - loss: 0.8031 - accuracy: 0.6979 - val_loss: 0.9991 - val_accuracy: 0.7108 - 30ms/epoch - 5ms/step
# Epoch 165/1500
# 6/6 - 0s - loss: 0.6935 - accuracy: 0.7251 - val_loss: 0.9960 - val_accuracy: 0.6988 - 29ms/epoch - 5ms/step
# Epoch 166/1500
# 6/6 - 0s - loss: 0.7251 - accuracy: 0.7251 - val_loss: 0.9709 - val_accuracy: 0.6867 - 29ms/epoch - 5ms/step
# Epoch 167/1500
# 6/6 - 0s - loss: 0.8045 - accuracy: 0.6707 - val_loss: 0.9362 - val_accuracy: 0.6988 - 30ms/epoch - 5ms/step
# Epoch 168/1500
# 6/6 - 0s - loss: 0.7466 - accuracy: 0.6737 - val_loss: 0.9028 - val_accuracy: 0.7229 - 31ms/epoch - 5ms/step
# Epoch 169/1500
# 6/6 - 0s - loss: 0.7960 - accuracy: 0.7069 - val_loss: 0.8894 - val_accuracy: 0.7108 - 30ms/epoch - 5ms/step
# Epoch 170/1500
# 6/6 - 0s - loss: 0.8184 - accuracy: 0.6979 - val_loss: 0.9079 - val_accuracy: 0.7108 - 30ms/epoch - 5ms/step
# Epoch 171/1500
# 6/6 - 0s - loss: 0.7817 - accuracy: 0.7039 - val_loss: 0.9412 - val_accuracy: 0.6988 - 29ms/epoch - 5ms/step
# Epoch 172/1500
# 6/6 - 0s - loss: 0.7311 - accuracy: 0.7402 - val_loss: 0.9359 - val_accuracy: 0.6867 - 30ms/epoch - 5ms/step
# Epoch 173/1500
# 6/6 - 0s - loss: 0.8312 - accuracy: 0.6828 - val_loss: 0.9781 - val_accuracy: 0.6867 - 31ms/epoch - 5ms/step
# Epoch 174/1500
# 6/6 - 0s - loss: 0.7641 - accuracy: 0.6918 - val_loss: 1.0776 - val_accuracy: 0.6867 - 30ms/epoch - 5ms/step
# Epoch 175/1500
# 6/6 - 0s - loss: 0.8021 - accuracy: 0.6979 - val_loss: 1.1979 - val_accuracy: 0.6988 - 30ms/epoch - 5ms/step
# Epoch 176/1500
# 6/6 - 0s - loss: 0.8103 - accuracy: 0.6647 - val_loss: 1.2317 - val_accuracy: 0.7108 - 35ms/epoch - 6ms/step
# Epoch 177/1500
# 6/6 - 0s - loss: 0.8167 - accuracy: 0.7039 - val_loss: 1.1865 - val_accuracy: 0.7108 - 45ms/epoch - 7ms/step
# Epoch 178/1500
# 6/6 - 0s - loss: 0.7948 - accuracy: 0.7130 - val_loss: 1.1283 - val_accuracy: 0.7349 - 40ms/epoch - 7ms/step
# Epoch 179/1500
# 6/6 - 0s - loss: 0.7017 - accuracy: 0.7523 - val_loss: 1.0901 - val_accuracy: 0.7349 - 37ms/epoch - 6ms/step
# Epoch 180/1500
# 6/6 - 0s - loss: 0.7450 - accuracy: 0.7130 - val_loss: 1.0360 - val_accuracy: 0.7349 - 40ms/epoch - 7ms/step
# Epoch 181/1500
# 6/6 - 0s - loss: 0.8146 - accuracy: 0.6949 - val_loss: 0.9359 - val_accuracy: 0.7470 - 39ms/epoch - 6ms/step
# Epoch 182/1500
# 6/6 - 0s - loss: 0.7482 - accuracy: 0.7130 - val_loss: 0.9293 - val_accuracy: 0.7470 - 35ms/epoch - 6ms/step
# Epoch 183/1500
# 6/6 - 0s - loss: 0.7804 - accuracy: 0.7221 - val_loss: 0.9097 - val_accuracy: 0.7229 - 36ms/epoch - 6ms/step
# Epoch 184/1500
# 6/6 - 0s - loss: 0.7620 - accuracy: 0.6737 - val_loss: 0.8960 - val_accuracy: 0.7229 - 34ms/epoch - 6ms/step
# Epoch 185/1500
# 6/6 - 0s - loss: 0.7863 - accuracy: 0.6737 - val_loss: 0.8877 - val_accuracy: 0.7470 - 36ms/epoch - 6ms/step
# Epoch 186/1500
# 6/6 - 0s - loss: 0.7718 - accuracy: 0.7039 - val_loss: 0.8903 - val_accuracy: 0.7590 - 36ms/epoch - 6ms/step
# Epoch 187/1500
# 6/6 - 0s - loss: 0.7126 - accuracy: 0.7190 - val_loss: 0.8918 - val_accuracy: 0.7590 - 38ms/epoch - 6ms/step
# Epoch 188/1500
# 6/6 - 0s - loss: 0.7648 - accuracy: 0.6979 - val_loss: 0.8869 - val_accuracy: 0.7952 - 34ms/epoch - 6ms/step
# Epoch 189/1500
# 6/6 - 0s - loss: 0.7669 - accuracy: 0.7069 - val_loss: 0.8792 - val_accuracy: 0.7952 - 31ms/epoch - 5ms/step
# Epoch 190/1500
# 6/6 - 0s - loss: 0.7377 - accuracy: 0.7523 - val_loss: 0.8727 - val_accuracy: 0.7831 - 33ms/epoch - 5ms/step
# Epoch 191/1500
# 6/6 - 0s - loss: 0.7278 - accuracy: 0.7432 - val_loss: 0.8623 - val_accuracy: 0.7831 - 31ms/epoch - 5ms/step
# Epoch 192/1500
# 6/6 - 0s - loss: 0.7532 - accuracy: 0.7100 - val_loss: 0.8619 - val_accuracy: 0.7831 - 33ms/epoch - 5ms/step
# Epoch 193/1500
# 6/6 - 0s - loss: 0.7429 - accuracy: 0.7251 - val_loss: 0.8964 - val_accuracy: 0.7711 - 32ms/epoch - 5ms/step
# Epoch 194/1500
# 6/6 - 0s - loss: 0.7003 - accuracy: 0.7221 - val_loss: 0.9431 - val_accuracy: 0.7590 - 38ms/epoch - 6ms/step
# Epoch 195/1500
# 6/6 - 0s - loss: 0.7293 - accuracy: 0.7160 - val_loss: 0.9438 - val_accuracy: 0.7470 - 33ms/epoch - 6ms/step
# Epoch 196/1500
# 6/6 - 0s - loss: 0.6827 - accuracy: 0.7160 - val_loss: 0.9360 - val_accuracy: 0.7470 - 38ms/epoch - 6ms/step
# Epoch 197/1500
# 6/6 - 0s - loss: 0.7771 - accuracy: 0.6918 - val_loss: 0.9261 - val_accuracy: 0.7349 - 74ms/epoch - 12ms/step
# Epoch 198/1500
# 6/6 - 0s - loss: 0.7678 - accuracy: 0.7039 - val_loss: 0.9244 - val_accuracy: 0.7229 - 41ms/epoch - 7ms/step
# Epoch 199/1500
# 6/6 - 0s - loss: 0.7148 - accuracy: 0.7190 - val_loss: 0.9281 - val_accuracy: 0.6988 - 37ms/epoch - 6ms/step
# Epoch 200/1500
# 6/6 - 0s - loss: 0.7114 - accuracy: 0.7402 - val_loss: 0.9225 - val_accuracy: 0.6988 - 35ms/epoch - 6ms/step
# Epoch 201/1500
# 6/6 - 0s - loss: 0.7455 - accuracy: 0.7100 - val_loss: 0.9146 - val_accuracy: 0.6988 - 33ms/epoch - 5ms/step
# Epoch 202/1500
# 6/6 - 0s - loss: 0.6893 - accuracy: 0.7221 - val_loss: 0.9082 - val_accuracy: 0.7108 - 34ms/epoch - 6ms/step
# Epoch 203/1500
# 6/6 - 0s - loss: 0.7366 - accuracy: 0.7523 - val_loss: 0.9105 - val_accuracy: 0.7108 - 35ms/epoch - 6ms/step
# Epoch 204/1500
# 6/6 - 0s - loss: 0.7448 - accuracy: 0.7311 - val_loss: 0.9321 - val_accuracy: 0.7108 - 35ms/epoch - 6ms/step
# Epoch 205/1500
# 6/6 - 0s - loss: 0.8110 - accuracy: 0.6918 - val_loss: 0.9312 - val_accuracy: 0.7108 - 27ms/epoch - 5ms/step
# Epoch 206/1500
# 6/6 - 0s - loss: 0.8114 - accuracy: 0.6949 - val_loss: 0.9222 - val_accuracy: 0.7108 - 27ms/epoch - 5ms/step
# Epoch 207/1500
# 6/6 - 0s - loss: 0.6527 - accuracy: 0.7402 - val_loss: 0.9188 - val_accuracy: 0.7349 - 27ms/epoch - 5ms/step
# Epoch 208/1500
# 6/6 - 0s - loss: 0.7018 - accuracy: 0.7190 - val_loss: 0.9113 - val_accuracy: 0.7590 - 27ms/epoch - 5ms/step
# Epoch 209/1500
# 6/6 - 0s - loss: 0.7043 - accuracy: 0.7492 - val_loss: 0.8971 - val_accuracy: 0.7711 - 29ms/epoch - 5ms/step
# Epoch 210/1500
# 6/6 - 0s - loss: 0.7224 - accuracy: 0.7281 - val_loss: 0.8849 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 211/1500
# 6/6 - 0s - loss: 0.6780 - accuracy: 0.7462 - val_loss: 0.8854 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 212/1500
# 6/6 - 0s - loss: 0.7310 - accuracy: 0.7432 - val_loss: 0.8835 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 213/1500
# 6/6 - 0s - loss: 0.6919 - accuracy: 0.7372 - val_loss: 0.8627 - val_accuracy: 0.7590 - 50ms/epoch - 8ms/step
# Epoch 214/1500
# 6/6 - 0s - loss: 0.7113 - accuracy: 0.7523 - val_loss: 0.8493 - val_accuracy: 0.7470 - 32ms/epoch - 5ms/step
# Epoch 215/1500
# 6/6 - 0s - loss: 0.7350 - accuracy: 0.7069 - val_loss: 0.8698 - val_accuracy: 0.7470 - 26ms/epoch - 4ms/step
# Epoch 216/1500
# 6/6 - 0s - loss: 0.7350 - accuracy: 0.6888 - val_loss: 0.8699 - val_accuracy: 0.7470 - 27ms/epoch - 4ms/step
# Epoch 217/1500
# 6/6 - 0s - loss: 0.6680 - accuracy: 0.7372 - val_loss: 0.8466 - val_accuracy: 0.7590 - 31ms/epoch - 5ms/step
# Epoch 218/1500
# 6/6 - 0s - loss: 0.7236 - accuracy: 0.7402 - val_loss: 0.8240 - val_accuracy: 0.7831 - 30ms/epoch - 5ms/step
# Epoch 219/1500
# 6/6 - 0s - loss: 0.7013 - accuracy: 0.7523 - val_loss: 0.8213 - val_accuracy: 0.7831 - 31ms/epoch - 5ms/step
# Epoch 220/1500
# 6/6 - 0s - loss: 0.7775 - accuracy: 0.7130 - val_loss: 0.8261 - val_accuracy: 0.7952 - 29ms/epoch - 5ms/step
# Epoch 221/1500
# 6/6 - 0s - loss: 0.7050 - accuracy: 0.7130 - val_loss: 0.8374 - val_accuracy: 0.7711 - 29ms/epoch - 5ms/step
# Epoch 222/1500
# 6/6 - 0s - loss: 0.7044 - accuracy: 0.7311 - val_loss: 0.8547 - val_accuracy: 0.7711 - 29ms/epoch - 5ms/step
# Epoch 223/1500
# 6/6 - 0s - loss: 0.6950 - accuracy: 0.7402 - val_loss: 0.8994 - val_accuracy: 0.7711 - 29ms/epoch - 5ms/step
# Epoch 224/1500
# 6/6 - 0s - loss: 0.7242 - accuracy: 0.7281 - val_loss: 0.9327 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 225/1500
# 6/6 - 0s - loss: 0.7492 - accuracy: 0.7311 - val_loss: 0.9203 - val_accuracy: 0.7470 - 33ms/epoch - 5ms/step
# Epoch 226/1500
# 6/6 - 0s - loss: 0.7414 - accuracy: 0.7341 - val_loss: 0.9192 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 227/1500
# 6/6 - 0s - loss: 0.7012 - accuracy: 0.7402 - val_loss: 0.9168 - val_accuracy: 0.7108 - 31ms/epoch - 5ms/step
# Epoch 228/1500
# 6/6 - 0s - loss: 0.7101 - accuracy: 0.7100 - val_loss: 0.9150 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 229/1500
# 6/6 - 0s - loss: 0.7240 - accuracy: 0.7039 - val_loss: 0.9332 - val_accuracy: 0.7108 - 30ms/epoch - 5ms/step
# Epoch 230/1500
# 6/6 - 0s - loss: 0.7210 - accuracy: 0.7251 - val_loss: 0.8946 - val_accuracy: 0.7229 - 29ms/epoch - 5ms/step
# Epoch 231/1500
# 6/6 - 0s - loss: 0.6764 - accuracy: 0.7553 - val_loss: 0.8433 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 232/1500
# 6/6 - 0s - loss: 0.7526 - accuracy: 0.7251 - val_loss: 0.8280 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 233/1500
# 6/6 - 0s - loss: 0.7199 - accuracy: 0.6949 - val_loss: 0.8218 - val_accuracy: 0.7711 - 30ms/epoch - 5ms/step
# Epoch 234/1500
# 6/6 - 0s - loss: 0.6710 - accuracy: 0.7251 - val_loss: 0.8119 - val_accuracy: 0.7831 - 29ms/epoch - 5ms/step
# Epoch 235/1500
# 6/6 - 0s - loss: 0.7503 - accuracy: 0.6918 - val_loss: 0.8225 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 236/1500
# 6/6 - 0s - loss: 0.7220 - accuracy: 0.7009 - val_loss: 0.8327 - val_accuracy: 0.7349 - 29ms/epoch - 5ms/step
# Epoch 237/1500
# 6/6 - 0s - loss: 0.7618 - accuracy: 0.7069 - val_loss: 0.8501 - val_accuracy: 0.7470 - 31ms/epoch - 5ms/step
# Epoch 238/1500
# 6/6 - 0s - loss: 0.6878 - accuracy: 0.7311 - val_loss: 0.8562 - val_accuracy: 0.7349 - 29ms/epoch - 5ms/step
# Epoch 239/1500
# 6/6 - 0s - loss: 0.6963 - accuracy: 0.7039 - val_loss: 0.8487 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 240/1500
# 6/6 - 0s - loss: 0.7265 - accuracy: 0.7281 - val_loss: 0.8362 - val_accuracy: 0.7470 - 30ms/epoch - 5ms/step
# Epoch 241/1500
# 6/6 - 0s - loss: 0.6844 - accuracy: 0.7492 - val_loss: 0.8361 - val_accuracy: 0.7470 - 35ms/epoch - 6ms/step
# Epoch 242/1500
# 6/6 - 0s - loss: 0.6880 - accuracy: 0.7583 - val_loss: 0.8408 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 243/1500
# 6/6 - 0s - loss: 0.7983 - accuracy: 0.6798 - val_loss: 0.8617 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 244/1500
# 6/6 - 0s - loss: 0.6966 - accuracy: 0.7251 - val_loss: 0.8866 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 245/1500
# 6/6 - 0s - loss: 0.6891 - accuracy: 0.7100 - val_loss: 0.9083 - val_accuracy: 0.7349 - 36ms/epoch - 6ms/step
# Epoch 246/1500
# 6/6 - 0s - loss: 0.6858 - accuracy: 0.7462 - val_loss: 0.9010 - val_accuracy: 0.7349 - 27ms/epoch - 5ms/step
# Epoch 247/1500
# 6/6 - 0s - loss: 0.7241 - accuracy: 0.7009 - val_loss: 0.8640 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 248/1500
# 6/6 - 0s - loss: 0.7165 - accuracy: 0.7069 - val_loss: 0.8473 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 249/1500
# 6/6 - 0s - loss: 0.6586 - accuracy: 0.7734 - val_loss: 0.8306 - val_accuracy: 0.7470 - 31ms/epoch - 5ms/step
# Epoch 250/1500
# 6/6 - 0s - loss: 0.7681 - accuracy: 0.7281 - val_loss: 0.8264 - val_accuracy: 0.7590 - 31ms/epoch - 5ms/step
# Epoch 251/1500
# 6/6 - 0s - loss: 0.7669 - accuracy: 0.7130 - val_loss: 0.8457 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 252/1500
# 6/6 - 0s - loss: 0.7641 - accuracy: 0.7160 - val_loss: 0.8614 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 253/1500
# 6/6 - 0s - loss: 0.7352 - accuracy: 0.7221 - val_loss: 0.8725 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 254/1500
# 6/6 - 0s - loss: 0.7613 - accuracy: 0.7160 - val_loss: 0.8741 - val_accuracy: 0.7590 - 28ms/epoch - 5ms/step
# Epoch 255/1500
# 6/6 - 0s - loss: 0.6776 - accuracy: 0.7372 - val_loss: 0.8676 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 256/1500
# 6/6 - 0s - loss: 0.7164 - accuracy: 0.7311 - val_loss: 0.8556 - val_accuracy: 0.7711 - 29ms/epoch - 5ms/step
# Epoch 257/1500
# 6/6 - 0s - loss: 0.7359 - accuracy: 0.7372 - val_loss: 0.8524 - val_accuracy: 0.7711 - 29ms/epoch - 5ms/step
# Epoch 258/1500
# 6/6 - 0s - loss: 0.6735 - accuracy: 0.7402 - val_loss: 0.8526 - val_accuracy: 0.7711 - 30ms/epoch - 5ms/step
# Epoch 259/1500
# 6/6 - 0s - loss: 0.7501 - accuracy: 0.7341 - val_loss: 0.8472 - val_accuracy: 0.7711 - 35ms/epoch - 6ms/step
# Epoch 260/1500
# 6/6 - 0s - loss: 0.6480 - accuracy: 0.7704 - val_loss: 0.8390 - val_accuracy: 0.7470 - 34ms/epoch - 6ms/step
# Epoch 261/1500
# 6/6 - 0s - loss: 0.6878 - accuracy: 0.7402 - val_loss: 0.8323 - val_accuracy: 0.7349 - 34ms/epoch - 6ms/step
# Epoch 262/1500
# 6/6 - 0s - loss: 0.6217 - accuracy: 0.7462 - val_loss: 0.8312 - val_accuracy: 0.7590 - 31ms/epoch - 5ms/step
# Epoch 263/1500
# 6/6 - 0s - loss: 0.7038 - accuracy: 0.7341 - val_loss: 0.8297 - val_accuracy: 0.7711 - 30ms/epoch - 5ms/step
# Epoch 264/1500
# 6/6 - 0s - loss: 0.6753 - accuracy: 0.7613 - val_loss: 0.8418 - val_accuracy: 0.7470 - 31ms/epoch - 5ms/step
# Epoch 265/1500
# 6/6 - 0s - loss: 0.7346 - accuracy: 0.7311 - val_loss: 0.8900 - val_accuracy: 0.7470 - 30ms/epoch - 5ms/step
# Epoch 266/1500
# 6/6 - 0s - loss: 0.7705 - accuracy: 0.7221 - val_loss: 0.9177 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 267/1500
# 6/6 - 0s - loss: 0.7048 - accuracy: 0.7341 - val_loss: 0.9122 - val_accuracy: 0.7349 - 28ms/epoch - 5ms/step
# Epoch 268/1500
# 6/6 - 0s - loss: 0.6924 - accuracy: 0.7281 - val_loss: 0.9126 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 269/1500
# 6/6 - 0s - loss: 0.7229 - accuracy: 0.7492 - val_loss: 0.9163 - val_accuracy: 0.7470 - 28ms/epoch - 5ms/step
# Epoch 270/1500
# 6/6 - 0s - loss: 0.7180 - accuracy: 0.7341 - val_loss: 0.9179 - val_accuracy: 0.7349 - 30ms/epoch - 5ms/step
# Epoch 271/1500
# 6/6 - 0s - loss: 0.7237 - accuracy: 0.7221 - val_loss: 0.9205 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 272/1500
# 6/6 - 0s - loss: 0.6777 - accuracy: 0.7553 - val_loss: 0.9067 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 273/1500
# 6/6 - 0s - loss: 0.6674 - accuracy: 0.7704 - val_loss: 0.8983 - val_accuracy: 0.7470 - 28ms/epoch - 5ms/step
# Epoch 274/1500
# 6/6 - 0s - loss: 0.7613 - accuracy: 0.7009 - val_loss: 0.8885 - val_accuracy: 0.7470 - 28ms/epoch - 5ms/step
# Epoch 275/1500
# 6/6 - 0s - loss: 0.6591 - accuracy: 0.7583 - val_loss: 0.8794 - val_accuracy: 0.7349 - 27ms/epoch - 5ms/step
# Epoch 276/1500
# 6/6 - 0s - loss: 0.6756 - accuracy: 0.7432 - val_loss: 0.8706 - val_accuracy: 0.7349 - 31ms/epoch - 5ms/step
# Epoch 277/1500
# 6/6 - 0s - loss: 0.6963 - accuracy: 0.7251 - val_loss: 0.8643 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 278/1500
# 6/6 - 0s - loss: 0.6713 - accuracy: 0.7704 - val_loss: 0.8629 - val_accuracy: 0.7108 - 28ms/epoch - 5ms/step
# Epoch 279/1500
# 6/6 - 0s - loss: 0.6506 - accuracy: 0.7372 - val_loss: 0.8703 - val_accuracy: 0.7108 - 29ms/epoch - 5ms/step
# Epoch 280/1500
# 6/6 - 0s - loss: 0.6937 - accuracy: 0.7492 - val_loss: 0.8773 - val_accuracy: 0.7349 - 31ms/epoch - 5ms/step
# Epoch 281/1500
# 6/6 - 0s - loss: 0.6238 - accuracy: 0.7764 - val_loss: 0.8590 - val_accuracy: 0.7349 - 28ms/epoch - 5ms/step
# Epoch 282/1500
# 6/6 - 0s - loss: 0.6717 - accuracy: 0.7160 - val_loss: 0.8398 - val_accuracy: 0.7349 - 30ms/epoch - 5ms/step
# Epoch 283/1500
# 6/6 - 0s - loss: 0.7271 - accuracy: 0.7160 - val_loss: 0.8399 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 284/1500
# 6/6 - 0s - loss: 0.7249 - accuracy: 0.7100 - val_loss: 0.8069 - val_accuracy: 0.7349 - 32ms/epoch - 5ms/step
# Epoch 285/1500
# 6/6 - 0s - loss: 0.6895 - accuracy: 0.7281 - val_loss: 0.8006 - val_accuracy: 0.7229 - 33ms/epoch - 5ms/step
# Epoch 286/1500
# 6/6 - 0s - loss: 0.6749 - accuracy: 0.7311 - val_loss: 0.8037 - val_accuracy: 0.7229 - 27ms/epoch - 4ms/step
# Epoch 287/1500
# 6/6 - 0s - loss: 0.6576 - accuracy: 0.7311 - val_loss: 0.8115 - val_accuracy: 0.7229 - 28ms/epoch - 5ms/step
# Epoch 288/1500
# 6/6 - 0s - loss: 0.7103 - accuracy: 0.7221 - val_loss: 0.8156 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 289/1500
# 6/6 - 0s - loss: 0.7393 - accuracy: 0.7100 - val_loss: 0.8139 - val_accuracy: 0.7349 - 30ms/epoch - 5ms/step
# Epoch 290/1500
# 6/6 - 0s - loss: 0.6674 - accuracy: 0.7523 - val_loss: 0.8180 - val_accuracy: 0.7349 - 30ms/epoch - 5ms/step
# Epoch 291/1500
# 6/6 - 0s - loss: 0.6732 - accuracy: 0.7462 - val_loss: 0.8355 - val_accuracy: 0.7229 - 28ms/epoch - 5ms/step
# Epoch 292/1500
# 6/6 - 0s - loss: 0.7112 - accuracy: 0.7372 - val_loss: 0.8374 - val_accuracy: 0.7229 - 29ms/epoch - 5ms/step
# Epoch 293/1500
# 6/6 - 0s - loss: 0.7021 - accuracy: 0.7432 - val_loss: 0.8367 - val_accuracy: 0.7229 - 29ms/epoch - 5ms/step
# Epoch 294/1500
# 6/6 - 0s - loss: 0.6963 - accuracy: 0.7432 - val_loss: 0.8394 - val_accuracy: 0.7229 - 29ms/epoch - 5ms/step
# Epoch 295/1500
# 6/6 - 0s - loss: 0.6992 - accuracy: 0.7402 - val_loss: 0.8484 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 296/1500
# 6/6 - 0s - loss: 0.6379 - accuracy: 0.7462 - val_loss: 0.8453 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 297/1500
# 6/6 - 0s - loss: 0.6304 - accuracy: 0.7613 - val_loss: 0.8407 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 298/1500
# 6/6 - 0s - loss: 0.6500 - accuracy: 0.7432 - val_loss: 0.8519 - val_accuracy: 0.7229 - 29ms/epoch - 5ms/step
# Epoch 299/1500
# 6/6 - 0s - loss: 0.6919 - accuracy: 0.7190 - val_loss: 0.8454 - val_accuracy: 0.7108 - 29ms/epoch - 5ms/step
# Epoch 300/1500
# 6/6 - 0s - loss: 0.6977 - accuracy: 0.7553 - val_loss: 0.8454 - val_accuracy: 0.7229 - 31ms/epoch - 5ms/step
# Epoch 301/1500
# 6/6 - 0s - loss: 0.6180 - accuracy: 0.7462 - val_loss: 0.8092 - val_accuracy: 0.7711 - 30ms/epoch - 5ms/step
# Epoch 302/1500
# 6/6 - 0s - loss: 0.6557 - accuracy: 0.7462 - val_loss: 0.8067 - val_accuracy: 0.7711 - 30ms/epoch - 5ms/step
# Epoch 303/1500
# 6/6 - 0s - loss: 0.6679 - accuracy: 0.7704 - val_loss: 0.8126 - val_accuracy: 0.7590 - 31ms/epoch - 5ms/step
# Epoch 304/1500
# 6/6 - 0s - loss: 0.7341 - accuracy: 0.7221 - val_loss: 0.8098 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 305/1500
# 6/6 - 0s - loss: 0.6519 - accuracy: 0.7281 - val_loss: 0.7985 - val_accuracy: 0.7590 - 31ms/epoch - 5ms/step
# Epoch 306/1500
# 6/6 - 0s - loss: 0.7129 - accuracy: 0.7251 - val_loss: 0.7917 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 307/1500
# 6/6 - 0s - loss: 0.6103 - accuracy: 0.8006 - val_loss: 0.7912 - val_accuracy: 0.7590 - 31ms/epoch - 5ms/step
# Epoch 308/1500
# 6/6 - 0s - loss: 0.6705 - accuracy: 0.7553 - val_loss: 0.7934 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 309/1500
# 6/6 - 0s - loss: 0.6145 - accuracy: 0.7946 - val_loss: 0.8055 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 310/1500
# 6/6 - 0s - loss: 0.6317 - accuracy: 0.7583 - val_loss: 0.8233 - val_accuracy: 0.7711 - 34ms/epoch - 6ms/step
# Epoch 311/1500
# 6/6 - 0s - loss: 0.7140 - accuracy: 0.7523 - val_loss: 0.8682 - val_accuracy: 0.7470 - 30ms/epoch - 5ms/step
# Epoch 312/1500
# 6/6 - 0s - loss: 0.6570 - accuracy: 0.7281 - val_loss: 0.8897 - val_accuracy: 0.7349 - 69ms/epoch - 12ms/step
# Epoch 313/1500
# 6/6 - 0s - loss: 0.6893 - accuracy: 0.7613 - val_loss: 0.8951 - val_accuracy: 0.7470 - 28ms/epoch - 5ms/step
# Epoch 314/1500
# 6/6 - 0s - loss: 0.6414 - accuracy: 0.7613 - val_loss: 0.8299 - val_accuracy: 0.7711 - 31ms/epoch - 5ms/step
# Epoch 315/1500
# 6/6 - 0s - loss: 0.7122 - accuracy: 0.7221 - val_loss: 0.8327 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 316/1500
# 6/6 - 0s - loss: 0.6848 - accuracy: 0.7402 - val_loss: 0.8140 - val_accuracy: 0.7590 - 27ms/epoch - 5ms/step
# Epoch 317/1500
# 6/6 - 0s - loss: 0.7005 - accuracy: 0.7130 - val_loss: 0.8077 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 318/1500
# 6/6 - 0s - loss: 0.6977 - accuracy: 0.7492 - val_loss: 0.8207 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 319/1500
# 6/6 - 0s - loss: 0.6352 - accuracy: 0.7704 - val_loss: 0.8249 - val_accuracy: 0.7711 - 30ms/epoch - 5ms/step
# Epoch 320/1500
# 6/6 - 0s - loss: 0.6354 - accuracy: 0.7795 - val_loss: 0.8326 - val_accuracy: 0.7590 - 28ms/epoch - 5ms/step
# Epoch 321/1500
# 6/6 - 0s - loss: 0.6588 - accuracy: 0.7764 - val_loss: 0.8432 - val_accuracy: 0.7349 - 29ms/epoch - 5ms/step
# Epoch 322/1500
# 6/6 - 0s - loss: 0.6940 - accuracy: 0.7311 - val_loss: 0.8366 - val_accuracy: 0.7349 - 28ms/epoch - 5ms/step
# Epoch 323/1500
# 6/6 - 0s - loss: 0.6682 - accuracy: 0.7523 - val_loss: 0.8314 - val_accuracy: 0.7349 - 31ms/epoch - 5ms/step
# Epoch 324/1500
# 6/6 - 0s - loss: 0.6613 - accuracy: 0.7311 - val_loss: 0.8294 - val_accuracy: 0.7349 - 29ms/epoch - 5ms/step
# Epoch 325/1500
# 6/6 - 0s - loss: 0.7004 - accuracy: 0.7069 - val_loss: 0.8184 - val_accuracy: 0.7470 - 28ms/epoch - 5ms/step
# Epoch 326/1500
# 6/6 - 0s - loss: 0.6249 - accuracy: 0.7644 - val_loss: 0.8081 - val_accuracy: 0.7470 - 28ms/epoch - 5ms/step
# Epoch 327/1500
# 6/6 - 0s - loss: 0.6762 - accuracy: 0.7644 - val_loss: 0.8081 - val_accuracy: 0.7349 - 28ms/epoch - 5ms/step
# Epoch 328/1500
# 6/6 - 0s - loss: 0.6523 - accuracy: 0.7251 - val_loss: 0.8165 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 329/1500
# 6/6 - 0s - loss: 0.6801 - accuracy: 0.7613 - val_loss: 0.8223 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 330/1500
# 6/6 - 0s - loss: 0.7843 - accuracy: 0.7069 - val_loss: 0.8268 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 331/1500
# 6/6 - 0s - loss: 0.7218 - accuracy: 0.7069 - val_loss: 0.8237 - val_accuracy: 0.7349 - 29ms/epoch - 5ms/step
# Epoch 332/1500
# 6/6 - 0s - loss: 0.6777 - accuracy: 0.7221 - val_loss: 0.8066 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 333/1500
# 6/6 - 0s - loss: 0.6711 - accuracy: 0.7372 - val_loss: 0.7993 - val_accuracy: 0.7711 - 29ms/epoch - 5ms/step
# Epoch 334/1500
# 6/6 - 0s - loss: 0.6616 - accuracy: 0.7704 - val_loss: 0.8072 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 335/1500
# 6/6 - 0s - loss: 0.6545 - accuracy: 0.7553 - val_loss: 0.8085 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 336/1500
# 6/6 - 0s - loss: 0.6461 - accuracy: 0.7523 - val_loss: 0.8094 - val_accuracy: 0.7349 - 32ms/epoch - 5ms/step
# Epoch 337/1500
# 6/6 - 0s - loss: 0.6980 - accuracy: 0.7372 - val_loss: 0.8084 - val_accuracy: 0.7590 - 52ms/epoch - 9ms/step
# Epoch 338/1500
# 6/6 - 0s - loss: 0.7066 - accuracy: 0.7069 - val_loss: 0.8138 - val_accuracy: 0.7470 - 33ms/epoch - 6ms/step
# Epoch 339/1500
# 6/6 - 0s - loss: 0.6189 - accuracy: 0.7734 - val_loss: 0.8237 - val_accuracy: 0.7470 - 32ms/epoch - 5ms/step
# Epoch 340/1500
# 6/6 - 0s - loss: 0.7043 - accuracy: 0.7462 - val_loss: 0.8264 - val_accuracy: 0.7349 - 35ms/epoch - 6ms/step
# Epoch 341/1500
# 6/6 - 0s - loss: 0.7084 - accuracy: 0.7190 - val_loss: 0.8245 - val_accuracy: 0.7470 - 33ms/epoch - 6ms/step
# Epoch 342/1500
# 6/6 - 0s - loss: 0.5935 - accuracy: 0.7492 - val_loss: 0.8329 - val_accuracy: 0.6988 - 34ms/epoch - 6ms/step
# Epoch 343/1500
# 6/6 - 0s - loss: 0.7010 - accuracy: 0.7039 - val_loss: 0.8556 - val_accuracy: 0.6988 - 34ms/epoch - 6ms/step
# Epoch 344/1500
# 6/6 - 0s - loss: 0.6616 - accuracy: 0.7251 - val_loss: 0.8577 - val_accuracy: 0.6988 - 33ms/epoch - 6ms/step
# Epoch 345/1500
# 6/6 - 0s - loss: 0.6361 - accuracy: 0.7402 - val_loss: 0.8464 - val_accuracy: 0.7229 - 36ms/epoch - 6ms/step
# Epoch 346/1500
# 6/6 - 0s - loss: 0.6919 - accuracy: 0.7341 - val_loss: 0.8641 - val_accuracy: 0.7108 - 33ms/epoch - 6ms/step
# Epoch 347/1500
# 6/6 - 0s - loss: 0.7148 - accuracy: 0.7190 - val_loss: 0.8877 - val_accuracy: 0.7108 - 35ms/epoch - 6ms/step
# Epoch 348/1500
# 6/6 - 0s - loss: 0.6517 - accuracy: 0.7644 - val_loss: 0.8746 - val_accuracy: 0.7229 - 34ms/epoch - 6ms/step
# Epoch 349/1500
# 6/6 - 0s - loss: 0.6985 - accuracy: 0.7462 - val_loss: 0.8678 - val_accuracy: 0.7229 - 70ms/epoch - 12ms/step
# Epoch 350/1500
# 6/6 - 0s - loss: 0.6653 - accuracy: 0.7523 - val_loss: 0.8623 - val_accuracy: 0.7229 - 45ms/epoch - 8ms/step
# Epoch 351/1500
# 6/6 - 0s - loss: 0.6590 - accuracy: 0.7644 - val_loss: 0.8689 - val_accuracy: 0.7108 - 33ms/epoch - 6ms/step
# Epoch 352/1500
# 6/6 - 0s - loss: 0.6579 - accuracy: 0.7492 - val_loss: 0.8564 - val_accuracy: 0.7108 - 34ms/epoch - 6ms/step
# Epoch 353/1500
# 6/6 - 0s - loss: 0.6797 - accuracy: 0.7492 - val_loss: 0.8343 - val_accuracy: 0.7108 - 31ms/epoch - 5ms/step
# Epoch 354/1500
# 6/6 - 0s - loss: 0.6533 - accuracy: 0.7553 - val_loss: 0.8290 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 355/1500
# 6/6 - 0s - loss: 0.6859 - accuracy: 0.7372 - val_loss: 0.8350 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 356/1500
# 6/6 - 0s - loss: 0.6853 - accuracy: 0.7613 - val_loss: 0.8457 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 357/1500
# 6/6 - 0s - loss: 0.6467 - accuracy: 0.7492 - val_loss: 0.8588 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 358/1500
# 6/6 - 0s - loss: 0.7294 - accuracy: 0.7372 - val_loss: 0.8666 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 359/1500
# 6/6 - 0s - loss: 0.6781 - accuracy: 0.7432 - val_loss: 0.8624 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 360/1500
# 6/6 - 0s - loss: 0.6659 - accuracy: 0.7583 - val_loss: 0.8619 - val_accuracy: 0.7590 - 31ms/epoch - 5ms/step
# Epoch 361/1500
# 6/6 - 0s - loss: 0.6831 - accuracy: 0.7402 - val_loss: 0.8421 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 362/1500
# 6/6 - 0s - loss: 0.6199 - accuracy: 0.7523 - val_loss: 0.8313 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 363/1500
# 6/6 - 0s - loss: 0.7489 - accuracy: 0.7190 - val_loss: 0.8282 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 364/1500
# 6/6 - 0s - loss: 0.6486 - accuracy: 0.7462 - val_loss: 0.8311 - val_accuracy: 0.7349 - 28ms/epoch - 5ms/step
# Epoch 365/1500
# 6/6 - 0s - loss: 0.6578 - accuracy: 0.7492 - val_loss: 0.8506 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 366/1500
# 6/6 - 0s - loss: 0.6599 - accuracy: 0.7311 - val_loss: 0.8512 - val_accuracy: 0.7349 - 32ms/epoch - 5ms/step
# Epoch 367/1500
# 6/6 - 0s - loss: 0.6882 - accuracy: 0.7341 - val_loss: 0.8419 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 368/1500
# 6/6 - 0s - loss: 0.6905 - accuracy: 0.7341 - val_loss: 0.8299 - val_accuracy: 0.7108 - 30ms/epoch - 5ms/step
# Epoch 369/1500
# 6/6 - 0s - loss: 0.6213 - accuracy: 0.7613 - val_loss: 0.8117 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 370/1500
# 6/6 - 0s - loss: 0.6685 - accuracy: 0.7523 - val_loss: 0.8087 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 371/1500
# 6/6 - 0s - loss: 0.6410 - accuracy: 0.7795 - val_loss: 0.8025 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 372/1500
# 6/6 - 0s - loss: 0.6901 - accuracy: 0.7311 - val_loss: 0.7930 - val_accuracy: 0.7470 - 31ms/epoch - 5ms/step
# Epoch 373/1500
# 6/6 - 0s - loss: 0.6958 - accuracy: 0.7341 - val_loss: 0.7939 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 374/1500
# 6/6 - 0s - loss: 0.6106 - accuracy: 0.7764 - val_loss: 0.7935 - val_accuracy: 0.7470 - 35ms/epoch - 6ms/step
# Epoch 375/1500
# 6/6 - 0s - loss: 0.6862 - accuracy: 0.7432 - val_loss: 0.7918 - val_accuracy: 0.7470 - 32ms/epoch - 5ms/step
# Epoch 376/1500
# 6/6 - 0s - loss: 0.6659 - accuracy: 0.7613 - val_loss: 0.7805 - val_accuracy: 0.7349 - 33ms/epoch - 6ms/step
# Epoch 377/1500
# 6/6 - 0s - loss: 0.6360 - accuracy: 0.7523 - val_loss: 0.7765 - val_accuracy: 0.7470 - 31ms/epoch - 5ms/step
# Epoch 378/1500
# 6/6 - 0s - loss: 0.6582 - accuracy: 0.7583 - val_loss: 0.7738 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 379/1500
# 6/6 - 0s - loss: 0.6652 - accuracy: 0.7523 - val_loss: 0.7756 - val_accuracy: 0.7470 - 28ms/epoch - 5ms/step
# Epoch 380/1500
# 6/6 - 0s - loss: 0.6555 - accuracy: 0.7583 - val_loss: 0.7739 - val_accuracy: 0.7711 - 30ms/epoch - 5ms/step
# Epoch 381/1500
# 6/6 - 0s - loss: 0.6241 - accuracy: 0.7523 - val_loss: 0.7859 - val_accuracy: 0.7349 - 29ms/epoch - 5ms/step
# Epoch 382/1500
# 6/6 - 0s - loss: 0.5879 - accuracy: 0.7976 - val_loss: 0.8014 - val_accuracy: 0.7229 - 31ms/epoch - 5ms/step
# Epoch 383/1500
# 6/6 - 0s - loss: 0.6253 - accuracy: 0.7583 - val_loss: 0.8100 - val_accuracy: 0.7349 - 30ms/epoch - 5ms/step
# Epoch 384/1500
# 6/6 - 0s - loss: 0.6555 - accuracy: 0.7583 - val_loss: 0.8067 - val_accuracy: 0.7349 - 30ms/epoch - 5ms/step
# Epoch 385/1500
# 6/6 - 0s - loss: 0.6344 - accuracy: 0.7523 - val_loss: 0.7938 - val_accuracy: 0.7108 - 31ms/epoch - 5ms/step
# Epoch 386/1500
# 6/6 - 0s - loss: 0.6761 - accuracy: 0.7130 - val_loss: 0.7978 - val_accuracy: 0.6867 - 30ms/epoch - 5ms/step
# Epoch 387/1500
# 6/6 - 0s - loss: 0.7042 - accuracy: 0.7372 - val_loss: 0.8169 - val_accuracy: 0.6988 - 29ms/epoch - 5ms/step
# Epoch 388/1500
# ...
# 6/6 - 0s - loss: 0.5395 - accuracy: 0.7915 - val_loss: 1.0187 - val_accuracy: 0.7590 - 51ms/epoch - 8ms/step
# Epoch 1374/1500
# 6/6 - 0s - loss: 0.5478 - accuracy: 0.8066 - val_loss: 1.0321 - val_accuracy: 0.7711 - 30ms/epoch - 5ms/step
# Epoch 1375/1500
# 6/6 - 0s - loss: 0.5223 - accuracy: 0.8157 - val_loss: 1.0361 - val_accuracy: 0.7590 - 28ms/epoch - 5ms/step
# Epoch 1376/1500
# 6/6 - 0s - loss: 0.5797 - accuracy: 0.8006 - val_loss: 1.0368 - val_accuracy: 0.7831 - 27ms/epoch - 4ms/step
# Epoch 1377/1500
# 6/6 - 0s - loss: 0.5792 - accuracy: 0.8036 - val_loss: 0.9725 - val_accuracy: 0.7711 - 28ms/epoch - 5ms/step
# Epoch 1378/1500
# 6/6 - 0s - loss: 0.5662 - accuracy: 0.7825 - val_loss: 0.9269 - val_accuracy: 0.7711 - 31ms/epoch - 5ms/step
# Epoch 1379/1500
# 6/6 - 0s - loss: 0.6369 - accuracy: 0.7644 - val_loss: 0.9430 - val_accuracy: 0.7470 - 30ms/epoch - 5ms/step
# Epoch 1380/1500
# 6/6 - 0s - loss: 0.5682 - accuracy: 0.7734 - val_loss: 0.9584 - val_accuracy: 0.7349 - 32ms/epoch - 5ms/step
# Epoch 1381/1500
# 6/6 - 0s - loss: 0.5423 - accuracy: 0.7885 - val_loss: 0.9796 - val_accuracy: 0.7229 - 28ms/epoch - 5ms/step
# Epoch 1382/1500
# 6/6 - 0s - loss: 0.5504 - accuracy: 0.8006 - val_loss: 0.9612 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 1383/1500
# 6/6 - 0s - loss: 0.5407 - accuracy: 0.7825 - val_loss: 0.9547 - val_accuracy: 0.7470 - 32ms/epoch - 5ms/step
# Epoch 1384/1500
# 6/6 - 0s - loss: 0.5722 - accuracy: 0.7976 - val_loss: 0.9185 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 1385/1500
# 6/6 - 0s - loss: 0.5842 - accuracy: 0.7795 - val_loss: 0.8910 - val_accuracy: 0.7831 - 31ms/epoch - 5ms/step
# Epoch 1386/1500
# 6/6 - 0s - loss: 0.5695 - accuracy: 0.7372 - val_loss: 0.8796 - val_accuracy: 0.7952 - 30ms/epoch - 5ms/step
# Epoch 1387/1500
# 6/6 - 0s - loss: 0.5589 - accuracy: 0.7976 - val_loss: 0.8672 - val_accuracy: 0.7952 - 30ms/epoch - 5ms/step
# Epoch 1388/1500
# 6/6 - 0s - loss: 0.6044 - accuracy: 0.7734 - val_loss: 0.8639 - val_accuracy: 0.7831 - 30ms/epoch - 5ms/step
# Epoch 1389/1500
# 6/6 - 0s - loss: 0.5259 - accuracy: 0.7764 - val_loss: 0.8655 - val_accuracy: 0.7952 - 71ms/epoch - 12ms/step
# Epoch 1390/1500
# 6/6 - 0s - loss: 0.5982 - accuracy: 0.8036 - val_loss: 0.8684 - val_accuracy: 0.7831 - 30ms/epoch - 5ms/step
# Epoch 1391/1500
# 6/6 - 0s - loss: 0.5938 - accuracy: 0.7613 - val_loss: 0.8682 - val_accuracy: 0.7952 - 27ms/epoch - 5ms/step
# Epoch 1392/1500
# 6/6 - 0s - loss: 0.5238 - accuracy: 0.8157 - val_loss: 0.8616 - val_accuracy: 0.7831 - 30ms/epoch - 5ms/step
# Epoch 1393/1500
# 6/6 - 0s - loss: 0.6034 - accuracy: 0.7915 - val_loss: 0.8632 - val_accuracy: 0.8072 - 29ms/epoch - 5ms/step
# Epoch 1394/1500
# 6/6 - 0s - loss: 0.5829 - accuracy: 0.7795 - val_loss: 0.8753 - val_accuracy: 0.7831 - 30ms/epoch - 5ms/step
# Epoch 1395/1500
# 6/6 - 0s - loss: 0.5827 - accuracy: 0.7885 - val_loss: 0.8786 - val_accuracy: 0.7711 - 31ms/epoch - 5ms/step
# Epoch 1396/1500
# 6/6 - 0s - loss: 0.5371 - accuracy: 0.7946 - val_loss: 0.8767 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 1397/1500
# 6/6 - 0s - loss: 0.5533 - accuracy: 0.7825 - val_loss: 0.8988 - val_accuracy: 0.7229 - 30ms/epoch - 5ms/step
# Epoch 1398/1500
# 6/6 - 0s - loss: 0.5614 - accuracy: 0.8036 - val_loss: 0.9015 - val_accuracy: 0.7349 - 30ms/epoch - 5ms/step
# Epoch 1399/1500
# 6/6 - 0s - loss: 0.5650 - accuracy: 0.7795 - val_loss: 0.9005 - val_accuracy: 0.7590 - 28ms/epoch - 5ms/step
# Epoch 1400/1500
# 6/6 - 0s - loss: 0.5517 - accuracy: 0.7976 - val_loss: 0.9094 - val_accuracy: 0.7711 - 30ms/epoch - 5ms/step
# Epoch 1401/1500
# 6/6 - 0s - loss: 0.5960 - accuracy: 0.7946 - val_loss: 0.9013 - val_accuracy: 0.7831 - 51ms/epoch - 9ms/step
# Epoch 1402/1500
# 6/6 - 0s - loss: 0.5351 - accuracy: 0.8036 - val_loss: 0.9091 - val_accuracy: 0.7831 - 31ms/epoch - 5ms/step
# Epoch 1403/1500
# 6/6 - 0s - loss: 0.5540 - accuracy: 0.7704 - val_loss: 0.9188 - val_accuracy: 0.7711 - 28ms/epoch - 5ms/step
# Epoch 1404/1500
# 6/6 - 0s - loss: 0.5587 - accuracy: 0.7946 - val_loss: 0.9123 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 1405/1500
# 6/6 - 0s - loss: 0.5445 - accuracy: 0.8218 - val_loss: 0.9061 - val_accuracy: 0.7590 - 31ms/epoch - 5ms/step
# Epoch 1406/1500
# 6/6 - 0s - loss: 0.5798 - accuracy: 0.7855 - val_loss: 0.9557 - val_accuracy: 0.7590 - 33ms/epoch - 5ms/step
# Epoch 1407/1500
# 6/6 - 0s - loss: 0.5693 - accuracy: 0.8036 - val_loss: 0.9616 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 1408/1500
# 6/6 - 0s - loss: 0.5247 - accuracy: 0.7946 - val_loss: 0.9537 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 1409/1500
# 6/6 - 0s - loss: 0.5681 - accuracy: 0.7795 - val_loss: 0.9558 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 1410/1500
# 6/6 - 0s - loss: 0.5432 - accuracy: 0.7885 - val_loss: 0.9922 - val_accuracy: 0.7711 - 29ms/epoch - 5ms/step
# Epoch 1411/1500
# 6/6 - 0s - loss: 0.5599 - accuracy: 0.7734 - val_loss: 1.0105 - val_accuracy: 0.7590 - 31ms/epoch - 5ms/step
# Epoch 1412/1500
# 6/6 - 0s - loss: 0.5324 - accuracy: 0.8127 - val_loss: 1.0028 - val_accuracy: 0.7590 - 32ms/epoch - 5ms/step
# Epoch 1413/1500
# 6/6 - 0s - loss: 0.5298 - accuracy: 0.7795 - val_loss: 1.0112 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 1414/1500
# 6/6 - 0s - loss: 0.5803 - accuracy: 0.7855 - val_loss: 1.0480 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 1415/1500
# 6/6 - 0s - loss: 0.5164 - accuracy: 0.7855 - val_loss: 1.0568 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 1416/1500
# 6/6 - 0s - loss: 0.4993 - accuracy: 0.8218 - val_loss: 1.0535 - val_accuracy: 0.7590 - 28ms/epoch - 5ms/step
# Epoch 1417/1500
# 6/6 - 0s - loss: 0.5872 - accuracy: 0.7764 - val_loss: 1.0650 - val_accuracy: 0.7711 - 30ms/epoch - 5ms/step
# Epoch 1418/1500
# 6/6 - 0s - loss: 0.5990 - accuracy: 0.7613 - val_loss: 1.0101 - val_accuracy: 0.7711 - 28ms/epoch - 5ms/step
# Epoch 1419/1500
# 6/6 - 0s - loss: 0.5504 - accuracy: 0.7764 - val_loss: 0.9723 - val_accuracy: 0.7711 - 29ms/epoch - 5ms/step
# Epoch 1420/1500
# 6/6 - 0s - loss: 0.5622 - accuracy: 0.7855 - val_loss: 0.9787 - val_accuracy: 0.7711 - 32ms/epoch - 5ms/step
# Epoch 1421/1500
# 6/6 - 0s - loss: 0.5948 - accuracy: 0.7885 - val_loss: 0.9784 - val_accuracy: 0.7711 - 29ms/epoch - 5ms/step
# Epoch 1422/1500
# 6/6 - 0s - loss: 0.5681 - accuracy: 0.7825 - val_loss: 0.9934 - val_accuracy: 0.7711 - 30ms/epoch - 5ms/step
# Epoch 1423/1500
# 6/6 - 0s - loss: 0.5891 - accuracy: 0.7613 - val_loss: 1.0058 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 1424/1500
# 6/6 - 0s - loss: 0.6006 - accuracy: 0.7764 - val_loss: 1.0033 - val_accuracy: 0.7470 - 30ms/epoch - 5ms/step
# Epoch 1425/1500
# 6/6 - 0s - loss: 0.6088 - accuracy: 0.7704 - val_loss: 0.9824 - val_accuracy: 0.7470 - 30ms/epoch - 5ms/step
# Epoch 1426/1500
# 6/6 - 0s - loss: 0.5202 - accuracy: 0.8097 - val_loss: 0.9552 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 1427/1500
# 6/6 - 0s - loss: 0.5598 - accuracy: 0.8248 - val_loss: 0.9423 - val_accuracy: 0.7711 - 30ms/epoch - 5ms/step
# Epoch 1428/1500
# 6/6 - 0s - loss: 0.5545 - accuracy: 0.8066 - val_loss: 0.9462 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 1429/1500
# 6/6 - 0s - loss: 0.5005 - accuracy: 0.8187 - val_loss: 0.9347 - val_accuracy: 0.7590 - 48ms/epoch - 8ms/step
# Epoch 1430/1500
# 6/6 - 0s - loss: 0.5606 - accuracy: 0.7825 - val_loss: 0.9266 - val_accuracy: 0.7831 - 27ms/epoch - 4ms/step
# Epoch 1431/1500
# 6/6 - 0s - loss: 0.5424 - accuracy: 0.7976 - val_loss: 0.9270 - val_accuracy: 0.7831 - 29ms/epoch - 5ms/step
# Epoch 1432/1500
# 6/6 - 0s - loss: 0.5666 - accuracy: 0.7855 - val_loss: 0.9340 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 1433/1500
# 6/6 - 0s - loss: 0.5513 - accuracy: 0.7855 - val_loss: 0.9541 - val_accuracy: 0.7470 - 28ms/epoch - 5ms/step
# Epoch 1434/1500
# 6/6 - 0s - loss: 0.5714 - accuracy: 0.7795 - val_loss: 1.0906 - val_accuracy: 0.7349 - 28ms/epoch - 5ms/step
# Epoch 1435/1500
# 6/6 - 0s - loss: 0.4913 - accuracy: 0.8338 - val_loss: 1.1532 - val_accuracy: 0.7349 - 28ms/epoch - 5ms/step
# Epoch 1436/1500
# 6/6 - 0s - loss: 0.5649 - accuracy: 0.7976 - val_loss: 1.1842 - val_accuracy: 0.7108 - 31ms/epoch - 5ms/step
# Epoch 1437/1500
# 6/6 - 0s - loss: 0.5583 - accuracy: 0.7976 - val_loss: 1.1317 - val_accuracy: 0.7108 - 38ms/epoch - 6ms/step
# Epoch 1438/1500
# 6/6 - 0s - loss: 0.5384 - accuracy: 0.7946 - val_loss: 1.1090 - val_accuracy: 0.7349 - 39ms/epoch - 7ms/step
# Epoch 1439/1500
# 6/6 - 0s - loss: 0.5207 - accuracy: 0.8066 - val_loss: 1.0863 - val_accuracy: 0.7349 - 36ms/epoch - 6ms/step
# Epoch 1440/1500
# 6/6 - 0s - loss: 0.5322 - accuracy: 0.7946 - val_loss: 1.0861 - val_accuracy: 0.7349 - 33ms/epoch - 6ms/step
# Epoch 1441/1500
# 6/6 - 0s - loss: 0.5232 - accuracy: 0.8157 - val_loss: 1.0730 - val_accuracy: 0.7470 - 30ms/epoch - 5ms/step
# Epoch 1442/1500
# 6/6 - 0s - loss: 0.5429 - accuracy: 0.8006 - val_loss: 1.0614 - val_accuracy: 0.7470 - 28ms/epoch - 5ms/step
# Epoch 1443/1500
# 6/6 - 0s - loss: 0.5419 - accuracy: 0.7825 - val_loss: 1.0588 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 1444/1500
# 6/6 - 0s - loss: 0.5443 - accuracy: 0.7946 - val_loss: 1.0804 - val_accuracy: 0.7349 - 29ms/epoch - 5ms/step
# Epoch 1445/1500
# 6/6 - 0s - loss: 0.5393 - accuracy: 0.7885 - val_loss: 1.0830 - val_accuracy: 0.7349 - 29ms/epoch - 5ms/step
# Epoch 1446/1500
# 6/6 - 0s - loss: 0.5255 - accuracy: 0.7946 - val_loss: 1.0472 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 1447/1500
# 6/6 - 0s - loss: 0.5355 - accuracy: 0.7885 - val_loss: 1.0547 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 1448/1500
# 6/6 - 0s - loss: 0.5792 - accuracy: 0.7674 - val_loss: 1.0628 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 1449/1500
# 6/6 - 0s - loss: 0.5131 - accuracy: 0.8127 - val_loss: 1.0664 - val_accuracy: 0.7711 - 29ms/epoch - 5ms/step
# Epoch 1450/1500
# 6/6 - 0s - loss: 0.5512 - accuracy: 0.7885 - val_loss: 1.0788 - val_accuracy: 0.7711 - 30ms/epoch - 5ms/step
# Epoch 1451/1500
# 6/6 - 0s - loss: 0.5582 - accuracy: 0.8036 - val_loss: 1.1021 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 1452/1500
# 6/6 - 0s - loss: 0.5009 - accuracy: 0.8218 - val_loss: 1.0928 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 1453/1500
# 6/6 - 0s - loss: 0.5022 - accuracy: 0.8187 - val_loss: 1.0954 - val_accuracy: 0.7229 - 29ms/epoch - 5ms/step
# Epoch 1454/1500
# 6/6 - 0s - loss: 0.5388 - accuracy: 0.8066 - val_loss: 1.0880 - val_accuracy: 0.7229 - 28ms/epoch - 5ms/step
# Epoch 1455/1500
# 6/6 - 0s - loss: 0.5560 - accuracy: 0.8036 - val_loss: 1.0449 - val_accuracy: 0.7349 - 29ms/epoch - 5ms/step
# Epoch 1456/1500
# 6/6 - 0s - loss: 0.5308 - accuracy: 0.7915 - val_loss: 1.0479 - val_accuracy: 0.7470 - 30ms/epoch - 5ms/step
# Epoch 1457/1500
# 6/6 - 0s - loss: 0.4856 - accuracy: 0.8248 - val_loss: 1.0176 - val_accuracy: 0.7470 - 47ms/epoch - 8ms/step
# Epoch 1458/1500
# 6/6 - 0s - loss: 0.5111 - accuracy: 0.8097 - val_loss: 0.9937 - val_accuracy: 0.7470 - 34ms/epoch - 6ms/step
# Epoch 1459/1500
# 6/6 - 0s - loss: 0.5047 - accuracy: 0.8127 - val_loss: 0.9619 - val_accuracy: 0.7590 - 28ms/epoch - 5ms/step
# Epoch 1460/1500
# 6/6 - 0s - loss: 0.5578 - accuracy: 0.7885 - val_loss: 0.9334 - val_accuracy: 0.7590 - 28ms/epoch - 5ms/step
# Epoch 1461/1500
# 6/6 - 0s - loss: 0.5516 - accuracy: 0.7885 - val_loss: 0.9183 - val_accuracy: 0.7470 - 30ms/epoch - 5ms/step
# Epoch 1462/1500
# 6/6 - 0s - loss: 0.5327 - accuracy: 0.8066 - val_loss: 0.9120 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 1463/1500
# 6/6 - 0s - loss: 0.4948 - accuracy: 0.8278 - val_loss: 0.9251 - val_accuracy: 0.7349 - 28ms/epoch - 5ms/step
# Epoch 1464/1500
# 6/6 - 0s - loss: 0.5654 - accuracy: 0.7855 - val_loss: 0.9369 - val_accuracy: 0.7349 - 29ms/epoch - 5ms/step
# Epoch 1465/1500
# 6/6 - 0s - loss: 0.5980 - accuracy: 0.7704 - val_loss: 0.9524 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 1466/1500
# 6/6 - 0s - loss: 0.5325 - accuracy: 0.7764 - val_loss: 0.9360 - val_accuracy: 0.7590 - 31ms/epoch - 5ms/step
# Epoch 1467/1500
# 6/6 - 0s - loss: 0.4665 - accuracy: 0.8338 - val_loss: 0.9208 - val_accuracy: 0.7349 - 30ms/epoch - 5ms/step
# Epoch 1468/1500
# 6/6 - 0s - loss: 0.5134 - accuracy: 0.7976 - val_loss: 0.9030 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 1469/1500
# 6/6 - 0s - loss: 0.4927 - accuracy: 0.8066 - val_loss: 0.8826 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 1470/1500
# 6/6 - 0s - loss: 0.5097 - accuracy: 0.7976 - val_loss: 0.8710 - val_accuracy: 0.7831 - 29ms/epoch - 5ms/step
# Epoch 1471/1500
# 6/6 - 0s - loss: 0.6081 - accuracy: 0.7734 - val_loss: 0.8573 - val_accuracy: 0.7831 - 29ms/epoch - 5ms/step
# Epoch 1472/1500
# 6/6 - 0s - loss: 0.4773 - accuracy: 0.8399 - val_loss: 0.8446 - val_accuracy: 0.7952 - 29ms/epoch - 5ms/step
# Epoch 1473/1500
# 6/6 - 0s - loss: 0.4934 - accuracy: 0.8399 - val_loss: 0.8347 - val_accuracy: 0.7952 - 30ms/epoch - 5ms/step
# Epoch 1474/1500
# 6/6 - 0s - loss: 0.5983 - accuracy: 0.7644 - val_loss: 0.8316 - val_accuracy: 0.7952 - 30ms/epoch - 5ms/step
# Epoch 1475/1500
# 6/6 - 0s - loss: 0.5570 - accuracy: 0.7885 - val_loss: 0.8530 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 1476/1500
# 6/6 - 0s - loss: 0.5507 - accuracy: 0.7795 - val_loss: 0.8419 - val_accuracy: 0.7711 - 28ms/epoch - 5ms/step
# Epoch 1477/1500
# 6/6 - 0s - loss: 0.5800 - accuracy: 0.7946 - val_loss: 0.8260 - val_accuracy: 0.7711 - 29ms/epoch - 5ms/step
# Epoch 1478/1500
# 6/6 - 0s - loss: 0.5522 - accuracy: 0.7825 - val_loss: 0.8485 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 1479/1500
# 6/6 - 0s - loss: 0.5576 - accuracy: 0.7976 - val_loss: 0.8699 - val_accuracy: 0.7711 - 28ms/epoch - 5ms/step
# Epoch 1480/1500
# 6/6 - 0s - loss: 0.5591 - accuracy: 0.8066 - val_loss: 0.9395 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 1481/1500
# 6/6 - 0s - loss: 0.5509 - accuracy: 0.8006 - val_loss: 0.9874 - val_accuracy: 0.7349 - 29ms/epoch - 5ms/step
# Epoch 1482/1500
# 6/6 - 0s - loss: 0.4980 - accuracy: 0.7976 - val_loss: 0.9719 - val_accuracy: 0.7470 - 30ms/epoch - 5ms/step
# Epoch 1483/1500
# 6/6 - 0s - loss: 0.5567 - accuracy: 0.8127 - val_loss: 0.9420 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 1484/1500
# 6/6 - 0s - loss: 0.5427 - accuracy: 0.7976 - val_loss: 0.9211 - val_accuracy: 0.7470 - 29ms/epoch - 5ms/step
# Epoch 1485/1500
# 6/6 - 0s - loss: 0.5671 - accuracy: 0.7915 - val_loss: 0.9317 - val_accuracy: 0.7349 - 49ms/epoch - 8ms/step
# Epoch 1486/1500
# 6/6 - 0s - loss: 0.5414 - accuracy: 0.8157 - val_loss: 0.9331 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step
# Epoch 1487/1500
# 6/6 - 0s - loss: 0.5745 - accuracy: 0.7764 - val_loss: 0.9419 - val_accuracy: 0.7590 - 31ms/epoch - 5ms/step
# Epoch 1488/1500
# 6/6 - 0s - loss: 0.5521 - accuracy: 0.7946 - val_loss: 0.9417 - val_accuracy: 0.7590 - 30ms/epoch - 5ms/step
# Epoch 1489/1500
# 6/6 - 0s - loss: 0.5887 - accuracy: 0.7885 - val_loss: 0.9476 - val_accuracy: 0.7470 - 86ms/epoch - 14ms/step
# Epoch 1490/1500
# 6/6 - 0s - loss: 0.5208 - accuracy: 0.7946 - val_loss: 0.9702 - val_accuracy: 0.7349 - 27ms/epoch - 4ms/step
# Epoch 1491/1500
# 6/6 - 0s - loss: 0.5289 - accuracy: 0.8127 - val_loss: 0.9319 - val_accuracy: 0.7590 - 26ms/epoch - 4ms/step
# Epoch 1492/1500
# 6/6 - 0s - loss: 0.4904 - accuracy: 0.8036 - val_loss: 0.8882 - val_accuracy: 0.7470 - 28ms/epoch - 5ms/step
# Epoch 1493/1500
# 6/6 - 0s - loss: 0.5599 - accuracy: 0.7825 - val_loss: 0.8763 - val_accuracy: 0.7470 - 30ms/epoch - 5ms/step
# Epoch 1494/1500
# 6/6 - 0s - loss: 0.5515 - accuracy: 0.7825 - val_loss: 0.8663 - val_accuracy: 0.7349 - 30ms/epoch - 5ms/step
# Epoch 1495/1500
# 6/6 - 0s - loss: 0.4878 - accuracy: 0.8369 - val_loss: 0.8575 - val_accuracy: 0.6988 - 29ms/epoch - 5ms/step
# Epoch 1496/1500
# 6/6 - 0s - loss: 0.5876 - accuracy: 0.7885 - val_loss: 0.8454 - val_accuracy: 0.7349 - 30ms/epoch - 5ms/step
# Epoch 1497/1500
# 6/6 - 0s - loss: 0.5196 - accuracy: 0.7885 - val_loss: 0.8298 - val_accuracy: 0.7349 - 28ms/epoch - 5ms/step
# Epoch 1498/1500
# 6/6 - 0s - loss: 0.5343 - accuracy: 0.8157 - val_loss: 0.8028 - val_accuracy: 0.7711 - 30ms/epoch - 5ms/step
# Epoch 1499/1500
# 6/6 - 0s - loss: 0.5789 - accuracy: 0.7734 - val_loss: 0.8006 - val_accuracy: 0.7711 - 31ms/epoch - 5ms/step
# Epoch 1500/1500
# 6/6 - 0s - loss: 0.5716 - accuracy: 0.7764 - val_loss: 0.8064 - val_accuracy: 0.7590 - 29ms/epoch - 5ms/step

# %% [markdown]
# # Plotagem das métricas de treinamento:

# %%
def plot_training_history(history):
    acc = history.history['accuracy']
    loss = history.history['loss']
    epochs = range(1, len(acc) + 1)

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
    fig.suptitle('Métricas de Treinamento')

    ax1.plot(epochs, acc, 'bo-', label='Acurácia de Treinamento')
    ax1.set_title('Acurácia de Treinamento')
    ax1.set_xlabel('Épocas')
    ax1.set_ylabel('Acurácia')
    ax1.legend()

    ax2.plot(epochs, loss, 'ro-', label='Perda de Treinamento')
    ax2.set_title('Perda de Treinamento')
    ax2.set_xlabel('Épocas')
    ax2.set_ylabel('Perda')
    ax2.legend()

    if 'val_accuracy' in history.history:
        val_acc = history.history['val_accuracy']
        val_loss = history.history['val_loss']
        ax1.plot(epochs, val_acc, 'g-', label='Acurácia de Validação')
        ax2.plot(epochs, val_loss, 'm-', label='Perda de Validação')
        ax1.legend()
        ax2.legend()

    plt.tight_layout()
    plt.show()

plot_training_history(history)

# %% [markdown]
# # Leitura dos registros de teste:

# %%
csv_path_testing_gases = "Datasets/Ibrahim-dataset/Gas-80-20-dataset/test_samples.csv"
with open(csv_path_testing_gases, mode = 'r') as file:
    csv_reader_testing_gases = csv.reader(file)
    next(csv_reader_testing_gases)
    
    test_samples = []
    for row in csv_reader_testing_gases:
        test_samples.append([float(x) for x in row])

csv_path_testing_faults = "Datasets/Ibrahim-dataset/Gas-80-20-dataset/test_labels.csv"
with open(csv_path_testing_faults, mode = 'r') as file:
    csv_reader_testing_faults = csv.reader(file)
    next(csv_reader_testing_faults)
    
    test_labels = []
    for row in csv_reader_testing_faults:
        test_labels.append(float(row[0]))

# %% [markdown]
# # Normalização dos testes:

# %%
# Normalização logarítmica dos gases
test_samples = np.array(test_samples)
# test_samples = np.log(test_samples + epsilon)

# normalização dos gases de teste
scaled_test_samples = scaler.transform(test_samples)

# normalização das rótulos de teste
test_labels = np.array(test_labels)
test_labels = test_labels.flatten()
int_scaled_test_labels = (test_labels.astype(float)).astype(int)
int_scaled_test_labels = np.array(int_scaled_test_labels)

# %% [markdown]
# # Teste e análise do modelo:

# %%
# realizando predições com o modelo treinado
y_pred = functional_model.predict(scaled_test_samples)
y_pred_classes = np.argmax(y_pred, axis=1)

# avaliando o modelo
test_loss, test_accuracy = functional_model.evaluate(scaled_test_samples, 
                                                   int_scaled_test_labels, 
                                                   verbose=0)
balanced_acc = balanced_accuracy_score(int_scaled_test_labels, y_pred_classes)
print(f"Balanced Accuracy: {balanced_acc:.4f}")
print(f"Acurácia no conjunto de teste: {test_accuracy:.4f}")
print(f"Perda no conjunto de teste: {test_loss:.4f}")
print("\nRelatório de Classificação:")
print(classification_report(int_scaled_test_labels, y_pred_classes, zero_division=0))

# matriz de confusão
cm = confusion_matrix(int_scaled_test_labels, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Matriz de Confusão')
plt.ylabel('Rótulo Verdadeiro')
plt.xlabel('Rótulo Previsto')
plt.show()
# Out:
# 4/4 [==============================] - 0s 1ms/step
# Balanced Accuracy: 0.8448
# Acurácia no conjunto de teste: 0.8558
# Perda no conjunto de teste: 0.6883
#
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#            0       0.83      1.00      0.91        15
#            1       1.00      0.78      0.88         9
#            2       1.00      0.53      0.70        15
#            3       0.73      0.92      0.81        24
#            4       0.89      0.94      0.92        18
#            5       0.88      0.88      0.88         8
#            6       0.93      0.87      0.90        15
#
#     accuracy                           0.86       104
#    macro avg       0.89      0.84      0.86       104
# weighted avg       0.88      0.86      0.85       104
